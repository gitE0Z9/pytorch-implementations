# %%
from pathlib import Path

import albumentations as A
import matplotlib.pyplot as plt
import torch
import torchinfo
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader
from torchlake.common.controller.evaluator import ClassificationEvaluator
from torchlake.common.datasets.imagenet import IMAGENET_DARKNET_CLASS_NAMES
from torchlake.common.utils.platform import get_file_size, get_num_workers
from torchlake.image_classification.models.darknet19 import DarkNet19

# %% [markdown]
# # Setting

# %%
BATCH_SIZE = 32

# %%
artifact_path = Path("../../artifacts/darknet19")
artifact_path.mkdir(exist_ok=True)

data_path = Path("F://imagenet/ILSVRC")

# %%
device = torch.device("cuda:0")

# %% [markdown]
# # data

# %%
IMAGE_SIZE = 448

# %%
# preprocess = A.Compose(
#     [
#         A.HorizontalFlip(),
#         A.ColorJitter(),
#         A.Resize(IMAGE_SIZE, IMAGE_SIZE),
#         ToTensorV2(),
#         A.Normalize(0, 1),
#     ]
# )

# %%
# image folder is enough for training

# dataset = torchvision.datasets.ImageFolder(
#     data_path.joinpath("Data").joinpath("CLS-LOC").joinpath("train").as_posix(),
#     transform=preprocess,
# )

# %%
# train_loader = DataLoader(
#     dataset,
#     batch_size=BATCH_SIZE,
#     shuffle=True,
#     drop_last=True,
#     pin_memory=True,
#     num_workers=get_num_workers(),
# )

# %%
NUM_CLASS = 1000

# %% [markdown]
# # model

# %%
model = DarkNet19(output_size=NUM_CLASS).to(device)

# %%
torchinfo.summary(model)
# Out:
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# DarkNet19                                          --
# ├─Sequential: 1-1                                  --
# │    └─Conv2dNormActivation: 2-1                   --
# │    │    └─Conv2d: 3-1                            864
# │    │    └─BatchNorm2d: 3-2                       64
# │    │    └─LeakyReLU: 3-3                         --
# │    └─MaxPool2d: 2-2                              --
# │    └─Conv2dNormActivation: 2-3                   --
# │    │    └─Conv2d: 3-4                            18,432
# │    │    └─BatchNorm2d: 3-5                       128
# │    │    └─LeakyReLU: 3-6                         --
# │    └─MaxPool2d: 2-4                              --
# ├─Sequential: 1-2                                  --
# │    └─BottleNeck: 2-5                             --
# │    │    └─Sequential: 3-7                        156,288
# │    └─MaxPool2d: 2-6                              --
# │    └─BottleNeck: 2-7                             --
# │    │    └─Sequential: 3-8                        623,872
# │    └─MaxPool2d: 2-8                              --
# │    └─BottleNeck: 2-9                             --
# │    │    └─Sequential: 3-9                        3,805,184
# │    └─MaxPool2d: 2-10                             --
# │    └─BottleNeck: 2-11                            --
# │    │    └─Sequential: 3-10                       15,212,544
# ├─Sequential: 1-3                                  --
# │    └─FlattenFeature: 2-12                        --
# │    │    └─Sequential: 3-11                       --
# │    └─Linear: 2-13                                1,025,000
# ===========================================================================
# Total params: 20,842,376
# Trainable params: 20,842,376
# Non-trainable params: 0
# ===========================================================================

# %% [markdown]
# we will show how to convert from darknet weights, which is already trained on ImageNet :D

# %%
FORCE_INVALIDATE = False

weights_path = artifact_path.joinpath("darknet19_448.weights")
model_path = artifact_path.joinpath("darknet19_448.pth")


if (weights_path.exists() and not model_path.exists()) or FORCE_INVALIDATE:
    from torchlake.image_classification.helpers.convertor_darknet19 import DarkNet19Convertor
    convertor = DarkNet19Convertor()
    remaining_bits = convertor.run(weights_path, model)
    
    assert remaining_bits == 0, "still bits not transferred"
    
    torch.save(model.state_dict(), model_path)
# Out:
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# Conv2dNormActivation
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# Conv2dNormActivation
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting conv
# finish converting conv
# conv / linear
# remaning: 0

# %%
model.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
test_preprocess = A.Compose(
    [
        A.Resize(IMAGE_SIZE, IMAGE_SIZE),
        A.Normalize(0, 1),
        ToTensorV2(),
    ]
)

# %%
# debug here
from torchlake.common.utils.image import load_image
img = load_image("F://imagenet/ILSVRC/Data/CLS-LOC/test/ILSVRC2012_test_00000002.JPEG", is_numpy=True)
img = test_preprocess(image=img)["image"]
img = img.unsqueeze_(0).cuda()

# %%
model.eval()
with torch.no_grad():
    print(IMAGENET_DARKNET_CLASS_NAMES[model(img).argmax(1)])
# Out:
# magpie

# %% [markdown]
# # inference

# %%
get_file_size(model_path)
# Out:
# '79.6MiB'

# %%
model.load_state_dict(torch.load(model_path.as_posix()))
# Out:
# <All keys matched successfully>

# %%
test_preprocess = A.Compose(
    [
        A.Resize(IMAGE_SIZE, IMAGE_SIZE),
        A.Normalize(0, 1),
        ToTensorV2(),
    ]
)

# %%
from torchlake.common.datasets.imagenet import ImageNetFromXML

# %%
test_dataset = ImageNetFromXML(
    data_path,
    label_encode="darknet",
    transform=test_preprocess,
)

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    pin_memory=True,
    num_workers=get_num_workers(),
)

# %%
evaluator = ClassificationEvaluator(NUM_CLASS, device)

# %%
confusion_matrix = evaluator.run(test_loader, model)
# Out:
# 100%|██████████| 1563/1563 [09:10<00:00,  2.84it/s]
# [[35  0  0 ...  0  0  0]
#  [ 0 37  0 ...  0  0  0]
#  [ 0  0 25 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 31  0  0]
#  [ 0  0  0 ...  0 44  0]
#  [ 0  0  0 ...  0  0 36]]

# %%
per_class_acc = evaluator.get_per_class_accuracy(confusion_matrix)
evaluator.show_per_class_accuracy(IMAGENET_DARKNET_CLASS_NAMES[:1000], per_class_acc)
# Out:
# kit fox   : 0.7
# English setter: 0.74
# Siberian husky: 0.5
# Australian terrier: 0.46
# English springer: 0.9
# grey whale: 0.86
# lesser panda: 0.92
# Egyptian cat: 0.5
# ibex      : 0.98
# Persian cat: 0.92
# cougar    : 0.9
# gazelle   : 0.7
# porcupine : 0.88
# sea lion  : 0.84
# malamute  : 0.76
# badger    : 0.88
# Great Dane: 0.58
# Walker hound: 0.74
# Welsh springer spaniel: 0.94
# whippet   : 0.8
# Scottish deerhound: 0.92
# killer whale: 0.98
# mink      : 0.76
# African elephant: 0.66
# Weimaraner: 0.94
# soft-coated wheaten terrier: 0.72
# Dandie Dinmont: 0.86
# red wolf  : 0.58
# Old English sheepdog: 0.92
# jaguar    : 0.74
# otterhound: 0.72
# bloodhound: 0.44
# Airedale  : 0.86
# hyena     : 0.88
# meerkat   : 0.86
# giant schnauzer: 0.84
# titi      : 0.62
# three-toed sloth: 0.98
# sorrel    : 0.98
# black-footed ferret: 0.66
# dalmatian : 0.96
# black-and-tan coonhound: 0.54
# papillon  : 0.92
# skunk     : 0.94
# Staffordshire bullterrier: 0.68
# Mexican hairless: 0.94
# Bouvier des Flandres: 0.78
# weasel    : 0.42
# miniature poodle: 0.52
# Cardigan  : 0.68
# malinois  : 0.92
# bighorn   : 0.68
# fox squirrel: 0.86
# colobus   : 0.92
# tiger cat : 0.28
# Lhasa     : 0.66
# impala    : 0.82
# coyote    : 0.68
# Yorkshire terrier: 0.56
# Newfoundland: 0.88
# brown bear: 0.94
# red fox   : 0.56
# Norwegian elkhound: 0.9
# Rottweiler: 0.92
# hartebeest: 0.94
# Saluki    : 0.78
# grey fox  : 0.74
# schipperke: 0.84
# Pekinese  : 0.86
# Brabancon griffon: 0.94
# West Highland white terrier: 0.92
# Sealyham terrier: 0.8
# guenon    : 0.8
# mongoose  : 0.8
# indri     : 0.88
# tiger     : 0.92
# Irish wolfhound: 0.64
# wild boar : 0.82
# EntleBucher: 0.8
# zebra     : 0.94
# ram       : 0.72
# French bulldog: 0.9
# orangutan : 0.86
# basenji   : 0.94
# leopard   : 0.8
# Bernese mountain dog: 0.92
# Maltese dog: 0.84
# Norfolk terrier: 0.74
# toy terrier: 0.54
# vizsla    : 0.9
# cairn     : 0.78
# squirrel monkey: 0.8
# groenendael: 0.78
# clumber   : 0.94
# Siamese cat: 0.92
# chimpanzee: 0.82
# komondor  : 0.9
# Afghan hound: 0.9
# Japanese spaniel: 0.8
# proboscis monkey: 1.0
# guinea pig: 0.8
# white wolf: 0.88
# ice bear  : 0.88
# gorilla   : 0.86
# borzoi    : 0.98
# toy poodle: 0.62
# Kerry blue terrier: 0.82
# ox        : 0.54
# Scotch terrier: 0.74
# Tibetan mastiff: 0.88
# spider monkey: 0.46
# Doberman  : 0.76
# Boston bull: 0.94
# Greater Swiss Mountain dog: 0.72
# Appenzeller: 0.26
# Shih-Tzu  : 0.72
# Irish water spaniel: 0.82
# Pomeranian: 0.94
# Bedlington terrier: 0.88
# warthog   : 0.96
# Arabian camel: 0.96
# siamang   : 0.76
# miniature schnauzer: 0.72
# collie    : 0.46
# golden retriever: 0.94
# Irish terrier: 0.7
# affenpinscher: 0.88
# Border collie: 0.74
# hare      : 0.88
# boxer     : 0.82
# silky terrier: 0.76
# beagle    : 0.86
# Leonberg  : 0.98
# German short-haired pointer: 0.84
# patas     : 0.66
# dhole     : 0.9
# baboon    : 0.9
# macaque   : 0.76
# Chesapeake Bay retriever: 0.8
# bull mastiff: 0.9
# kuvasz    : 0.74
# capuchin  : 0.78
# pug       : 0.96
# curly-coated retriever: 0.76
# Norwich terrier: 0.74
# flat-coated retriever: 0.78
# hog       : 0.58
# keeshond  : 0.92
# Eskimo dog: 0.46
# Brittany spaniel: 0.88
# standard poodle: 0.92
# Lakeland terrier: 0.74
# snow leopard: 0.9
# Gordon setter: 0.88
# dingo     : 0.76
# standard schnauzer: 0.82
# hamster   : 0.98
# Tibetan terrier: 0.82
# Arctic fox: 0.94
# wire-haired fox terrier: 0.66
# basset    : 0.88
# water buffalo: 0.92
# American black bear: 0.88
# Angora    : 0.94
# bison     : 0.94
# howler monkey: 0.88
# hippopotamus: 0.92
# chow      : 0.84
# giant panda: 0.94
# American Staffordshire terrier: 0.66
# Shetland sheepdog: 0.82
# Great Pyrenees: 0.8
# Chihuahua : 0.66
# tabby     : 0.54
# marmoset  : 0.82
# Labrador retriever: 0.88
# Saint Bernard: 0.96
# armadillo : 0.86
# Samoyed   : 0.98
# bluetick  : 0.88
# redbone   : 0.6
# polecat   : 0.48
# marmot    : 0.94
# kelpie    : 0.76
# gibbon    : 0.84
# llama     : 0.9
# miniature pinscher: 0.76
# wood rabbit: 0.78
# Italian greyhound: 0.88
# lion      : 0.96
# cocker spaniel: 0.84
# Irish setter: 0.84
# dugong    : 0.84
# Indian elephant: 0.52
# beaver    : 0.82
# Sussex spaniel: 0.74
# Pembroke  : 0.88
# Blenheim spaniel: 0.94
# Madagascar cat: 0.72
# Rhodesian ridgeback: 0.72
# lynx      : 0.76
# African hunting dog: 1.0
# langur    : 0.58
# Ibizan hound: 0.66
# timber wolf: 0.82
# cheetah   : 0.96
# English foxhound: 0.2
# briard    : 0.56
# sloth bear: 0.66
# Border terrier: 0.88
# German shepherd: 0.82
# otter     : 0.8
# koala     : 0.86
# tusker    : 0.6
# echidna   : 1.0
# wallaby   : 0.9
# platypus  : 0.8
# wombat    : 0.76
# revolver  : 0.9
# umbrella  : 0.68
# schooner  : 0.74
# soccer ball: 0.94
# accordion : 0.82
# ant       : 0.72
# starfish  : 0.86
# chambered nautilus: 0.88
# grand piano: 0.66
# laptop    : 0.28
# strawberry: 0.7
# airliner  : 0.98
# warplane  : 0.82
# airship   : 0.92
# balloon   : 0.92
# space shuttle: 0.86
# fireboat  : 0.92
# gondola   : 0.98
# speedboat : 0.86
# lifeboat  : 0.94
# canoe     : 0.96
# yawl      : 0.8
# catamaran : 0.74
# trimaran  : 0.8
# container ship: 0.86
# liner     : 0.9
# pirate    : 0.78
# aircraft carrier: 0.88
# submarine : 0.78
# wreck     : 0.92
# half track: 0.84
# tank      : 0.76
# missile   : 0.48
# bobsled   : 0.94
# dogsled   : 0.94
# bicycle-built-for-two: 0.86
# mountain bike: 0.78
# freight car: 1.0
# passenger car: 0.48
# barrow    : 0.78
# shopping cart: 0.84
# motor scooter: 0.88
# forklift  : 0.88
# electric locomotive: 0.86
# steam locomotive: 0.94
# amphibian : 0.68
# ambulance : 0.88
# beach wagon: 0.68
# cab       : 0.78
# convertible: 0.84
# jeep      : 0.8
# limousine : 0.78
# minivan   : 0.58
# Model T   : 1.0
# racer     : 0.74
# sports car: 0.58
# go-kart   : 0.94
# golfcart  : 0.8
# moped     : 0.72
# snowplow  : 0.94
# fire engine: 0.84
# garbage truck: 0.92
# pickup    : 0.76
# tow truck : 0.74
# trailer truck: 0.8
# moving van: 0.48
# police van: 0.82
# recreational vehicle: 0.88
# streetcar : 0.92
# snowmobile: 0.94
# tractor   : 0.84
# mobile home: 0.72
# tricycle  : 0.88
# unicycle  : 0.88
# horse cart: 0.86
# jinrikisha: 0.9
# oxcart    : 0.9
# bassinet  : 0.78
# cradle    : 0.44
# crib      : 0.8
# four-poster: 0.92
# bookcase  : 0.64
# china cabinet: 0.9
# medicine chest: 0.68
# chiffonier: 0.24
# table lamp: 0.56
# file      : 0.88
# park bench: 0.72
# barber chair: 0.64
# throne    : 0.74
# folding chair: 0.8
# rocking chair: 0.78
# studio couch: 0.84
# toilet seat: 0.7
# desk      : 0.64
# pool table: 0.86
# dining table: 0.8
# entertainment center: 0.88
# wardrobe  : 0.66
# Granny Smith: 0.9
# orange    : 0.74
# lemon     : 0.68
# fig       : 0.8
# pineapple : 0.9
# banana    : 0.88
# jackfruit : 0.94
# custard apple: 0.9
# pomegranate: 0.84
# acorn     : 0.98
# hip       : 0.94
# ear       : 0.46
# rapeseed  : 1.0
# corn      : 0.32
# buckeye   : 0.9
# organ     : 0.86
# upright   : 0.8
# chime     : 0.72
# drum      : 0.5
# gong      : 0.68
# maraca    : 0.78
# marimba   : 0.88
# steel drum: 0.9
# banjo     : 0.92
# cello     : 0.92
# violin    : 0.74
# harp      : 0.94
# acoustic guitar: 0.58
# electric guitar: 0.7
# cornet    : 0.68
# French horn: 0.8
# trombone  : 0.78
# harmonica : 0.76
# ocarina   : 0.86
# panpipe   : 0.84
# bassoon   : 0.86
# oboe      : 0.72
# sax       : 0.74
# flute     : 0.5
# daisy     : 0.98
# yellow lady's slipper: 1.0
# cliff     : 0.64
# valley    : 0.74
# alp       : 0.64
# volcano   : 0.84
# promontory: 0.56
# sandbar   : 0.68
# coral reef: 0.72
# lakeside  : 0.54
# seashore  : 0.48
# geyser    : 0.98
# hatchet   : 0.58
# cleaver   : 0.46
# letter opener: 0.3
# plane     : 0.82
# power drill: 0.6
# lawn mower: 0.9
# hammer    : 0.64
# corkscrew : 0.92
# can opener: 0.74
# plunger   : 0.6
# screwdriver: 0.38
# shovel    : 0.64
# plow      : 0.74
# chain saw : 0.9
# cock      : 0.82
# hen       : 0.88
# ostrich   : 0.98
# brambling : 0.86
# goldfinch : 0.94
# house finch: 0.94
# junco     : 1.0
# indigo bunting: 0.96
# robin     : 0.94
# bulbul    : 0.9
# jay       : 0.92
# magpie    : 0.92
# chickadee : 1.0
# water ouzel: 0.92
# kite      : 0.78
# bald eagle: 0.94
# vulture   : 0.98
# great grey owl: 0.98
# black grouse: 0.88
# ptarmigan : 0.86
# ruffed grouse: 0.82
# prairie chicken: 0.92
# peacock   : 0.92
# quail     : 0.9
# partridge : 0.76
# African grey: 0.94
# macaw     : 0.92
# sulphur-crested cockatoo: 0.92
# lorikeet  : 0.96
# coucal    : 0.88
# bee eater : 0.98
# hornbill  : 0.94
# hummingbird: 0.92
# jacamar   : 0.96
# toucan    : 0.9
# drake     : 0.86
# red-breasted merganser: 0.9
# goose     : 0.8
# black swan: 0.96
# white stork: 0.92
# black stork: 0.78
# spoonbill : 0.96
# flamingo  : 0.96
# American egret: 0.92
# little blue heron: 0.88
# bittern   : 0.84
# crane     : 0.66
# limpkin   : 1.0
# American coot: 0.96
# bustard   : 0.94
# ruddy turnstone: 1.0
# red-backed sandpiper: 0.88
# redshank  : 0.94
# dowitcher : 0.92
# oystercatcher: 0.92
# European gallinule: 0.94
# pelican   : 0.96
# king penguin: 0.92
# albatross : 0.96
# great white shark: 0.84
# tiger shark: 0.7
# hammerhead: 0.86
# electric ray: 0.74
# stingray  : 0.8
# barracouta: 0.78
# coho      : 0.9
# tench     : 0.92
# goldfish  : 0.94
# eel       : 0.58
# rock beauty: 0.88
# anemone fish: 0.82
# lionfish  : 0.94
# puffer    : 0.9
# sturgeon  : 0.86
# gar       : 0.72
# loggerhead: 0.76
# leatherback turtle: 0.64
# mud turtle: 0.64
# terrapin  : 0.62
# box turtle: 0.84
# banded gecko: 0.82
# common iguana: 0.84
# American chameleon: 0.52
# whiptail  : 0.84
# agama     : 0.82
# frilled lizard: 0.84
# alligator lizard: 0.7
# Gila monster: 0.76
# green lizard: 0.48
# African chameleon: 0.78
# Komodo dragon: 0.94
# triceratops: 0.94
# African crocodile: 0.72
# American alligator: 0.88
# thunder snake: 0.8
# ringneck snake: 0.92
# hognose snake: 0.54
# green snake: 0.72
# king snake: 0.82
# garter snake: 0.94
# water snake: 0.76
# vine snake: 0.64
# night snake: 0.34
# boa constrictor: 0.8
# rock python: 0.54
# Indian cobra: 0.78
# green mamba: 0.68
# sea snake : 0.74
# horned viper: 0.56
# diamondback: 0.76
# sidewinder: 0.3
# European fire salamander: 0.92
# common newt: 0.6
# eft       : 0.76
# spotted salamander: 0.88
# axolotl   : 0.9
# bullfrog  : 0.84
# tree frog : 0.88
# tailed frog: 0.42
# whistle   : 0.76
# wing      : 0.64
# paintbrush: 0.8
# hand blower: 0.7
# oxygen mask: 0.48
# snorkel   : 0.86
# loudspeaker: 0.56
# microphone: 0.52
# screen    : 0.12
# mouse     : 0.34
# electric fan: 0.82
# oil filter: 0.74
# strainer  : 0.66
# space heater: 0.56
# stove     : 0.5
# guillotine: 0.9
# barometer : 0.84
# rule      : 0.82
# odometer  : 0.96
# scale     : 0.7
# analog clock: 0.6
# digital clock: 0.68
# wall clock: 0.68
# hourglass : 0.98
# sundial   : 0.68
# parking meter: 0.94
# stopwatch : 0.52
# digital watch: 0.58
# stethoscope: 0.74
# syringe   : 0.68
# magnetic compass: 0.6
# binoculars: 0.72
# projector : 0.68
# sunglasses: 0.48
# loupe     : 0.38
# radio telescope: 0.9
# bow       : 0.72
# cannon    : 0.88
# assault rifle: 0.42
# rifle     : 0.46
# projectile: 0.34
# computer keyboard: 0.74
# typewriter keyboard: 0.66
# crane     : 0.76
# lighter   : 0.62
# abacus    : 0.88
# cash machine: 0.78
# slide rule: 0.74
# desktop computer: 0.56
# hand-held computer: 0.46
# notebook  : 0.36
# web site  : 0.98
# harvester : 0.78
# thresher  : 0.64
# printer   : 0.52
# slot      : 0.94
# vending machine: 0.96
# sewing machine: 0.86
# joystick  : 0.84
# switch    : 0.58
# hook      : 0.28
# car wheel : 0.44
# paddlewheel: 0.94
# pinwheel  : 0.88
# potter's wheel: 0.92
# gas pump  : 0.84
# carousel  : 0.98
# swing     : 0.82
# reel      : 0.7
# radiator  : 0.74
# puck      : 0.9
# hard disc : 0.86
# sunglass  : 0.12
# pick      : 0.7
# car mirror: 0.96
# solar dish: 0.72
# remote control: 0.84
# disk brake: 0.96
# buckle    : 0.56
# hair slide: 0.48
# knot      : 0.86
# combination lock: 0.72
# padlock   : 0.72
# nail      : 0.66
# safety pin: 0.68
# screw     : 0.92
# muzzle    : 0.56
# seat belt : 0.9
# ski       : 0.72
# candle    : 0.6
# jack-o'-lantern: 0.96
# spotlight : 0.26
# torch     : 0.74
# neck brace: 0.64
# pier      : 0.54
# tripod    : 0.74
# maypole   : 0.98
# mousetrap : 0.86
# spider web: 0.76
# trilobite : 0.96
# harvestman: 0.9
# scorpion  : 0.9
# black and gold garden spider: 0.86
# barn spider: 0.4
# garden spider: 0.6
# black widow: 0.9
# tarantula : 0.98
# wolf spider: 0.8
# tick      : 0.76
# centipede : 0.78
# isopod    : 0.68
# Dungeness crab: 0.88
# rock crab : 0.72
# fiddler crab: 0.68
# king crab : 0.74
# American lobster: 0.76
# spiny lobster: 0.84
# crayfish  : 0.54
# hermit crab: 0.92
# tiger beetle: 0.94
# ladybug   : 0.9
# ground beetle: 0.6
# long-horned beetle: 0.74
# leaf beetle: 0.62
# dung beetle: 0.88
# rhinoceros beetle: 0.92
# weevil    : 0.92
# fly       : 0.9
# bee       : 0.78
# grasshopper: 0.56
# cricket   : 0.62
# walking stick: 0.74
# cockroach : 0.74
# mantis    : 0.7
# cicada    : 0.94
# leafhopper: 0.92
# lacewing  : 0.84
# dragonfly : 0.84
# damselfly : 0.86
# admiral   : 1.0
# ringlet   : 0.9
# monarch   : 0.94
# cabbage butterfly: 0.86
# sulphur butterfly: 0.92
# lycaenid  : 0.94
# jellyfish : 0.88
# sea anemone: 0.7
# brain coral: 0.9
# flatworm  : 0.76
# nematode  : 0.92
# conch     : 0.76
# snail     : 0.86
# slug      : 0.84
# sea slug  : 0.88
# chiton    : 0.82
# sea urchin: 0.82
# sea cucumber: 0.8
# iron      : 0.84
# espresso maker: 0.72
# microwave : 0.66
# Dutch oven: 0.7
# rotisserie: 0.88
# toaster   : 0.68
# waffle iron: 0.78
# vacuum    : 0.82
# dishwasher: 0.6
# refrigerator: 0.8
# washer    : 0.84
# Crock Pot : 0.84
# frying pan: 0.54
# wok       : 0.52
# caldron   : 0.54
# coffeepot : 0.56
# teapot    : 0.84
# spatula   : 0.4
# altar     : 0.7
# triumphal arch: 0.94
# patio     : 0.6
# steel arch bridge: 0.82
# suspension bridge: 0.7
# viaduct   : 0.8
# barn      : 0.94
# greenhouse: 0.86
# palace    : 0.76
# monastery : 0.42
# library   : 0.6
# apiary    : 0.9
# boathouse : 0.92
# church    : 0.74
# mosque    : 0.84
# stupa     : 0.92
# planetarium: 0.96
# restaurant: 0.54
# cinema    : 0.76
# home theater: 0.66
# lumbermill: 0.76
# coil      : 0.68
# obelisk   : 0.86
# totem pole: 1.0
# castle    : 0.84
# prison    : 0.66
# grocery store: 0.66
# bakery    : 0.44
# barbershop: 0.66
# bookshop  : 0.66
# butcher shop: 0.74
# confectionery: 0.66
# shoe shop : 0.9
# tobacco shop: 0.42
# toyshop   : 0.62
# fountain  : 0.86
# cliff dwelling: 0.96
# yurt      : 0.98
# dock      : 0.54
# brass     : 0.94
# megalith  : 0.84
# bannister : 0.76
# breakwater: 0.72
# dam       : 0.86
# chainlink fence: 0.72
# picket fence: 0.9
# worm fence: 0.78
# stone wall: 0.84
# grille    : 0.72
# sliding door: 0.42
# turnstile : 0.8
# mountain tent: 0.9
# scoreboard: 0.84
# honeycomb : 0.6
# plate rack: 0.52
# pedestal  : 0.64
# beacon    : 0.82
# mashed potato: 0.8
# bell pepper: 0.84
# head cabbage: 0.9
# broccoli  : 0.94
# cauliflower: 0.86
# zucchini  : 0.7
# spaghetti squash: 0.82
# acorn squash: 0.84
# butternut squash: 0.72
# cucumber  : 0.62
# artichoke : 0.88
# cardoon   : 0.86
# mushroom  : 0.34
# shower curtain: 0.68
# jean      : 0.72
# carton    : 0.58
# handkerchief: 0.76
# sandal    : 0.7
# ashcan    : 0.54
# safe      : 0.86
# plate     : 0.5
# necklace  : 0.94
# croquet ball: 0.88
# fur coat  : 0.9
# thimble   : 0.66
# pajama    : 0.66
# running shoe: 0.84
# cocktail shaker: 0.64
# chest     : 0.74
# manhole cover: 0.92
# modem     : 0.64
# tub       : 0.3
# tray      : 0.56
# balance beam: 0.9
# bagel     : 0.68
# prayer rug: 0.72
# kimono    : 0.88
# hot pot   : 0.82
# whiskey jug: 0.54
# knee pad  : 0.86
# book jacket: 0.66
# spindle   : 0.88
# ski mask  : 0.76
# beer bottle: 0.8
# crash helmet: 0.94
# bottlecap : 0.7
# tile roof : 0.8
# mask      : 0.58
# maillot   : 0.16
# Petri dish: 0.66
# football helmet: 0.92
# bathing cap: 0.78
# teddy     : 0.82
# holster   : 0.72
# pop bottle: 0.72
# photocopier: 0.96
# vestment  : 0.62
# crossword puzzle: 0.84
# golf ball : 0.84
# trifle    : 0.94
# suit      : 0.6
# water tower: 0.94
# feather boa: 0.84
# cloak     : 0.4
# red wine  : 0.56
# drumstick : 0.52
# shield    : 0.6
# Christmas stocking: 0.92
# hoopskirt : 0.7
# menu      : 0.84
# stage     : 0.7
# bonnet    : 0.64
# meat loaf : 0.58
# baseball  : 0.82
# face powder: 0.76
# scabbard  : 0.8
# sunscreen : 0.5
# beer glass: 0.72
# hen-of-the-woods: 0.84
# guacamole : 0.76
# lampshade : 0.52
# wool      : 0.38
# hay       : 0.84
# bow tie   : 0.76
# mailbag   : 0.58
# water jug : 0.26
# bucket    : 0.56
# dishrag   : 0.98
# soup bowl : 0.58
# eggnog    : 0.48
# mortar    : 0.84
# trench coat: 0.58
# paddle    : 0.62
# chain     : 0.4
# swab      : 0.88
# mixing bowl: 0.82
# potpie    : 0.78
# wine bottle: 0.58
# shoji     : 0.86
# bulletproof vest: 0.58
# drilling platform: 0.94
# binder    : 0.64
# cardigan  : 0.8
# sweatshirt: 0.34
# pot       : 0.84
# birdhouse : 0.86
# hamper    : 0.72
# ping-pong ball: 0.9
# pencil box: 0.7
# pay-phone : 0.84
# consomme  : 0.6
# apron     : 0.78
# punching bag: 0.64
# backpack  : 0.48
# groom     : 0.82
# bearskin  : 0.9
# pencil sharpener: 0.62
# broom     : 0.68
# mosquito net: 0.9
# abaya     : 0.84
# mortarboard: 0.72
# poncho    : 0.7
# crutch    : 0.6
# Polaroid camera: 0.86
# space bar : 0.38
# cup       : 0.34
# racket    : 0.78
# traffic light: 0.82
# quill     : 0.82
# radio     : 0.58
# dough     : 0.44
# cuirass   : 0.52
# military uniform: 0.68
# lipstick  : 0.74
# shower cap: 0.84
# monitor   : 0.38
# oscilloscope: 0.94
# mitten    : 0.8
# brassiere : 0.56
# French loaf: 0.68
# vase      : 0.5
# milk can  : 0.7
# rugby ball: 0.82
# paper towel: 0.68
# earthstar : 1.0
# envelope  : 0.62
# miniskirt : 0.6
# cowboy hat: 0.76
# trolleybus: 0.98
# perfume   : 0.72
# bathtub   : 0.56
# hotdog    : 0.84
# coral fungus: 0.96
# bullet train: 0.94
# pillow    : 0.9
# toilet tissue: 0.5
# cassette  : 0.6
# carpenter's kit: 0.66
# ladle     : 0.36
# stinkhorn : 0.8
# lotion    : 0.52
# hair spray: 0.38
# academic gown: 0.48
# dome      : 0.7
# crate     : 0.56
# wig       : 0.86
# burrito   : 0.86
# pill bottle: 0.8
# chain mail: 0.74
# theater curtain: 0.88
# window shade: 0.76
# barrel    : 0.7
# washbasin : 0.84
# ballpoint : 0.6
# basketball: 1.0
# bath towel: 0.64
# cowboy boot: 0.72
# gown      : 0.5
# window screen: 0.7
# agaric    : 0.86
# cellular telephone: 0.72
# nipple    : 0.88
# barbell   : 0.66
# mailbox   : 0.74
# lab coat  : 0.8
# fire screen: 0.54
# minibus   : 0.82
# packet    : 0.52
# maze      : 0.88
# pole      : 0.54
# horizontal bar: 0.72
# sombrero  : 0.74
# pickelhaube: 0.82
# rain barrel: 0.84
# wallet    : 0.62
# cassette player: 0.26
# comic book: 0.72
# piggy bank: 0.86
# street sign: 0.78
# bell cote : 0.6
# fountain pen: 0.82
# Windsor tie: 0.32
# volleyball: 0.94
# overskirt : 0.2
# sarong    : 0.68
# purse     : 0.46
# bolo tie  : 0.86
# bib       : 0.7
# parachute : 0.94
# sleeping bag: 0.66
# television: 0.7
# swimming trunks: 0.56
# measuring cup: 0.66
# espresso  : 0.7
# pizza     : 0.82
# breastplate: 0.34
# shopping basket: 0.58
# wooden spoon: 0.7
# saltshaker: 0.74
# chocolate sauce: 0.5
# ballplayer: 0.76
# goblet    : 0.66
# gyromitra : 0.98
# stretcher : 0.54
# water bottle: 0.5
# dial telephone: 0.92
# soap dispenser: 0.62
# jersey    : 0.8
# school bus: 0.94
# jigsaw puzzle: 0.96
# plastic bag: 0.48
# reflex camera: 0.7
# diaper    : 0.74
# Band Aid  : 0.72
# ice lolly : 0.76
# velvet    : 0.18
# tennis ball: 0.8
# gasmask   : 0.86
# doormat   : 0.62
# Loafer    : 0.78
# ice cream : 0.62
# pretzel   : 0.8
# quilt     : 0.64
# maillot   : 0.38
# tape player: 0.4
# clog      : 0.58
# iPod      : 0.9
# bolete    : 0.76
# scuba diver: 0.88
# pitcher   : 0.48
# matchstick: 0.68
# bikini    : 0.62
# sock      : 0.7
# CD player : 0.54
# lens cap  : 0.54
# thatch    : 0.92
# vault     : 0.74
# beaker    : 0.5
# bubble    : 0.84
# cheeseburger: 0.92
# parallel bars: 0.66
# flagpole  : 0.8
# coffee mug: 0.54
# rubber eraser: 0.6
# stole     : 0.62
# carbonara : 0.88
# dumbbell  : 0.72

# %%
per_class_acc.mean()
# Out:
# 0.7596200000000001

# %%
plt.bar(IMAGENET_DARKNET_CLASS_NAMES[:1000], per_class_acc)
# Out:
# <BarContainer object of 1000 artists>

# %%
evaluator.plot_confusion_matrix(
    confusion_matrix,
    IMAGENET_DARKNET_CLASS_NAMES[:1000],
    "Blues",
    annot=False,
    figsize=(6, 4),
)
