# %%
from pathlib import Path

import albumentations as A
import matplotlib.pyplot as plt
import torch
import torchinfo
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader
from torchlake.common.controller.evaluator import ClassificationEvaluator
from torchlake.common.datasets.imagenet import IMAGENET_DARKNET_CLASS_NAMES
from torchlake.common.utils.platform import get_file_size, get_num_workers
from torchlake.image_classification.models.darknet53 import DarkNet53

# %% [markdown]
# # Setting

# %%
BATCH_SIZE = 32

# %%
artifact_path = Path("../../artifacts/darknet53")
artifact_path.mkdir(exist_ok=True)

data_path = Path("F://imagenet/ILSVRC")

# %%
DEVICE = torch.device("cuda:0")

# %% [markdown]
# # data

# %%
IMAGE_SIZE = 256

# %%
# preprocess = A.Compose(
#     [
#         A.HorizontalFlip(),
#         A.ColorJitter(),
#         A.Resize(IMAGE_SIZE, IMAGE_SIZE),
#         ToTensorV2(),
#         A.Normalize(0, 1),
#     ]
# )

# %%
# image folder is enough for training

# dataset = torchvision.datasets.ImageFolder(
#     data_path.joinpath("Data").joinpath("CLS-LOC").joinpath("train").as_posix(),
#     transform=preprocess,
# )

# %%
# train_loader = DataLoader(
#     dataset,
#     batch_size=BATCH_SIZE,
#     shuffle=True,
#     drop_last=True,
#     pin_memory=True,
#     num_workers=get_num_workers(),
# )

# %%
NUM_CLASS = 1000

# %% [markdown]
# # model

# %%
model = DarkNet53(output_size=NUM_CLASS).to(DEVICE)

# %%
torchinfo.summary(model)
# Out:
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# DarkNet53                                               --
# ├─Sequential: 1-1                                       --
# │    └─Conv2dNormActivation: 2-1                        --
# │    │    └─Conv2d: 3-1                                 864
# │    │    └─BatchNorm2d: 3-2                            64
# │    │    └─LeakyReLU: 3-3                              --
# ├─Sequential: 1-2                                       --
# │    └─Conv2dNormActivation: 2-2                        --
# │    │    └─Conv2d: 3-4                                 18,432
# │    │    └─BatchNorm2d: 3-5                            128
# │    │    └─LeakyReLU: 3-6                              --
# │    └─ResBlock: 2-3                                    --
# │    │    └─DarkNetBlock: 3-7                           20,672
# │    │    └─Identity: 3-8                               --
# │    └─Conv2dNormActivation: 2-4                        --
# │    │    └─Conv2d: 3-9                                 73,728
# │    │    └─BatchNorm2d: 3-10                           256
# │    │    └─LeakyReLU: 3-11                             --
# │    └─ResBlock: 2-5                                    --
# │    │    └─DarkNetBlock: 3-12                          82,304
# │    │    └─Identity: 3-13                              --
# │    └─ResBlock: 2-6                                    --
# │    │    └─DarkNetBlock: 3-14                          82,304
# │    │    └─Identity: 3-15                              --
# │    └─Conv2dNormActivation: 2-7                        --
# │    │    └─Conv2d: 3-16                                294,912
# │    │    └─BatchNorm2d: 3-17                           512
# │    │    └─LeakyReLU: 3-18                             --
# │    └─ResBlock: 2-8                                    --
# │    │    └─DarkNetBlock: 3-19                          328,448
# │    │    └─Identity: 3-20                              --
# │    └─ResBlock: 2-9                                    --
# │    │    └─DarkNetBlock: 3-21                          328,448
# │    │    └─Identity: 3-22                              --
# │    └─ResBlock: 2-10                                   --
# │    │    └─DarkNetBlock: 3-23                          328,448
# │    │    └─Identity: 3-24                              --
# │    └─ResBlock: 2-11                                   --
# │    │    └─DarkNetBlock: 3-25                          328,448
# │    │    └─Identity: 3-26                              --
# │    └─ResBlock: 2-12                                   --
# │    │    └─DarkNetBlock: 3-27                          328,448
# │    │    └─Identity: 3-28                              --
# │    └─ResBlock: 2-13                                   --
# │    │    └─DarkNetBlock: 3-29                          328,448
# │    │    └─Identity: 3-30                              --
# │    └─ResBlock: 2-14                                   --
# │    │    └─DarkNetBlock: 3-31                          328,448
# │    │    └─Identity: 3-32                              --
# │    └─ResBlock: 2-15                                   --
# │    │    └─DarkNetBlock: 3-33                          328,448
# │    │    └─Identity: 3-34                              --
# │    └─Conv2dNormActivation: 2-16                       --
# │    │    └─Conv2d: 3-35                                1,179,648
# │    │    └─BatchNorm2d: 3-36                           1,024
# │    │    └─LeakyReLU: 3-37                             --
# │    └─ResBlock: 2-17                                   --
# │    │    └─DarkNetBlock: 3-38                          1,312,256
# │    │    └─Identity: 3-39                              --
# │    └─ResBlock: 2-18                                   --
# │    │    └─DarkNetBlock: 3-40                          1,312,256
# │    │    └─Identity: 3-41                              --
# │    └─ResBlock: 2-19                                   --
# │    │    └─DarkNetBlock: 3-42                          1,312,256
# │    │    └─Identity: 3-43                              --
# │    └─ResBlock: 2-20                                   --
# │    │    └─DarkNetBlock: 3-44                          1,312,256
# │    │    └─Identity: 3-45                              --
# │    └─ResBlock: 2-21                                   --
# │    │    └─DarkNetBlock: 3-46                          1,312,256
# │    │    └─Identity: 3-47                              --
# │    └─ResBlock: 2-22                                   --
# │    │    └─DarkNetBlock: 3-48                          1,312,256
# │    │    └─Identity: 3-49                              --
# │    └─ResBlock: 2-23                                   --
# │    │    └─DarkNetBlock: 3-50                          1,312,256
# │    │    └─Identity: 3-51                              --
# │    └─ResBlock: 2-24                                   --
# │    │    └─DarkNetBlock: 3-52                          1,312,256
# │    │    └─Identity: 3-53                              --
# │    └─Conv2dNormActivation: 2-25                       --
# │    │    └─Conv2d: 3-54                                4,718,592
# │    │    └─BatchNorm2d: 3-55                           2,048
# │    │    └─LeakyReLU: 3-56                             --
# │    └─ResBlock: 2-26                                   --
# │    │    └─DarkNetBlock: 3-57                          5,245,952
# │    │    └─Identity: 3-58                              --
# │    └─ResBlock: 2-27                                   --
# │    │    └─DarkNetBlock: 3-59                          5,245,952
# │    │    └─Identity: 3-60                              --
# │    └─ResBlock: 2-28                                   --
# │    │    └─DarkNetBlock: 3-61                          5,245,952
# │    │    └─Identity: 3-62                              --
# │    └─ResBlock: 2-29                                   --
# │    │    └─DarkNetBlock: 3-63                          5,245,952
# │    │    └─Identity: 3-64                              --
# ├─Sequential: 1-3                                       --
# │    └─FlattenFeature: 2-30                             --
# │    │    └─Sequential: 3-65                            --
# │    └─Linear: 2-31                                     1,025,000
# ================================================================================
# Total params: 41,609,928
# Trainable params: 41,609,928
# Non-trainable params: 0
# ================================================================================

# %%
model_path = artifact_path.joinpath("darknet53_448.pth")

# %% [markdown]
# we will show how to convert from darknet weights, which is already trained on ImageNet :D

# %%
FORCE_INVALIDATE = False

weights_path = artifact_path.joinpath("darknet53_448.weights")

if (weights_path.exists() and not model_path.exists()) or FORCE_INVALIDATE:
    from torchlake.image_classification.helpers.convertor_darknet53 import DarkNet53Convertor
    convertor = DarkNet53Convertor()
    remaining_bits = convertor.run(weights_path, model)
    
    assert remaining_bits == 0, "still bits not transferred"
    
    torch.save(model.state_dict(), model_path)
# Out:
# Weights Header:  0 2 0 [102400000]
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# Conv2dNormActivation
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# Conv2dNormActivation
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# Conv2dNormActivation
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# Conv2dNormActivation
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# Conv2dNormActivation
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# Conv2dNormActivation
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting darknet 53 block
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting darknet 53 block
# start converting conv
# finish converting conv
# conv / linear
# remaning: 0

# %%
model.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
test_preprocess = A.Compose(
    [
        A.Resize(IMAGE_SIZE, IMAGE_SIZE),
        A.Normalize(0, 1),
        ToTensorV2(),
    ]
)

# %%
# debug here
from torchlake.common.utils.image import load_image
img = load_image("F://imagenet/ILSVRC/Data/CLS-LOC/test/ILSVRC2012_test_00000002.JPEG", is_numpy=True)
img = test_preprocess(image=img)["image"]
img = img.unsqueeze_(0).cuda()

# %%
model.eval()
with torch.no_grad():
    print(IMAGENET_DARKNET_CLASS_NAMES[model(img).argmax(1)])
# Out:
# magpie

# %% [markdown]
# # inference

# %%
VAL_IMAGE_SIZE = 448

# %%
model_path = artifact_path.joinpath("darknet53_448.pth")

# %%
get_file_size(model_path)
# Out:
# '158.98MiB'

# %%
model.load_state_dict(torch.load(model_path.as_posix()))
# Out:
# <All keys matched successfully>

# %%
test_preprocess = A.Compose(
    [
        A.Resize(VAL_IMAGE_SIZE, VAL_IMAGE_SIZE),
        A.Normalize(0, 1),
        ToTensorV2(),
    ]
)

# %%
from torchlake.common.datasets.imagenet import ImageNetFromXML

# %%
test_dataset = ImageNetFromXML(
    data_path,
    label_encode="darknet",
    transform=test_preprocess,
)

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    pin_memory=True,
    num_workers=get_num_workers(),
)

# %%
evaluator = ClassificationEvaluator(NUM_CLASS, DEVICE)

# %%
confusion_matrix = evaluator.run(test_loader, model)
# Out:
# 100%|██████████| 1563/1563 [13:13<00:00,  1.97it/s]
# [[32  0  0 ...  0  0  0]
#  [ 0 43  0 ...  0  0  0]
#  [ 0  0 35 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 35  0  0]
#  [ 0  0  0 ...  0 45  0]
#  [ 0  0  0 ...  0  0 38]]

# %%
per_class_acc = evaluator.get_per_class_accuracy(confusion_matrix)
evaluator.show_per_class_accuracy(IMAGENET_DARKNET_CLASS_NAMES[:1000], per_class_acc)
# Out:
# kit fox   : 0.64
# English setter: 0.86
# Siberian husky: 0.7
# Australian terrier: 0.5
# English springer: 0.96
# grey whale: 0.9
# lesser panda: 0.94
# Egyptian cat: 0.5
# ibex      : 0.96
# Persian cat: 0.86
# cougar    : 0.92
# gazelle   : 0.74
# porcupine : 0.9
# sea lion  : 0.88
# malamute  : 0.82
# badger    : 0.9
# Great Dane: 0.7
# Walker hound: 0.72
# Welsh springer spaniel: 0.94
# whippet   : 0.8
# Scottish deerhound: 0.92
# killer whale: 0.96
# mink      : 0.9
# African elephant: 0.7
# Weimaraner: 0.94
# soft-coated wheaten terrier: 0.72
# Dandie Dinmont: 0.9
# red wolf  : 0.58
# Old English sheepdog: 0.92
# jaguar    : 0.8
# otterhound: 0.76
# bloodhound: 0.52
# Airedale  : 0.88
# hyena     : 0.94
# meerkat   : 0.88
# giant schnauzer: 0.9
# titi      : 0.62
# three-toed sloth: 1.0
# sorrel    : 0.98
# black-footed ferret: 0.64
# dalmatian : 0.98
# black-and-tan coonhound: 0.64
# papillon  : 0.94
# skunk     : 0.94
# Staffordshire bullterrier: 0.74
# Mexican hairless: 0.94
# Bouvier des Flandres: 0.86
# weasel    : 0.42
# miniature poodle: 0.48
# Cardigan  : 0.72
# malinois  : 0.92
# bighorn   : 0.64
# fox squirrel: 0.88
# colobus   : 0.92
# tiger cat : 0.18
# Lhasa     : 0.72
# impala    : 0.86
# coyote    : 0.74
# Yorkshire terrier: 0.66
# Newfoundland: 0.9
# brown bear: 0.92
# red fox   : 0.64
# Norwegian elkhound: 0.92
# Rottweiler: 0.9
# hartebeest: 0.98
# Saluki    : 0.82
# grey fox  : 0.72
# schipperke: 0.92
# Pekinese  : 0.92
# Brabancon griffon: 0.9
# West Highland white terrier: 0.94
# Sealyham terrier: 0.84
# guenon    : 0.84
# mongoose  : 0.78
# indri     : 0.9
# tiger     : 0.96
# Irish wolfhound: 0.68
# wild boar : 0.82
# EntleBucher: 0.76
# zebra     : 0.96
# ram       : 0.72
# French bulldog: 0.92
# orangutan : 0.9
# basenji   : 0.92
# leopard   : 0.84
# Bernese mountain dog: 0.92
# Maltese dog: 0.82
# Norfolk terrier: 0.78
# toy terrier: 0.52
# vizsla    : 0.84
# cairn     : 0.86
# squirrel monkey: 0.82
# groenendael: 0.82
# clumber   : 0.94
# Siamese cat: 0.96
# chimpanzee: 0.9
# komondor  : 0.9
# Afghan hound: 0.92
# Japanese spaniel: 0.74
# proboscis monkey: 1.0
# guinea pig: 0.82
# white wolf: 0.88
# ice bear  : 0.92
# gorilla   : 0.88
# borzoi    : 0.98
# toy poodle: 0.62
# Kerry blue terrier: 0.84
# ox        : 0.62
# Scotch terrier: 0.84
# Tibetan mastiff: 0.98
# spider monkey: 0.48
# Doberman  : 0.78
# Boston bull: 0.92
# Greater Swiss Mountain dog: 0.82
# Appenzeller: 0.4
# Shih-Tzu  : 0.74
# Irish water spaniel: 0.86
# Pomeranian: 0.94
# Bedlington terrier: 0.92
# warthog   : 0.96
# Arabian camel: 0.94
# siamang   : 0.74
# miniature schnauzer: 0.68
# collie    : 0.66
# golden retriever: 0.88
# Irish terrier: 0.72
# affenpinscher: 0.8
# Border collie: 0.8
# hare      : 0.88
# boxer     : 0.84
# silky terrier: 0.78
# beagle    : 0.78
# Leonberg  : 1.0
# German short-haired pointer: 0.84
# patas     : 0.68
# dhole     : 0.92
# baboon    : 0.92
# macaque   : 0.76
# Chesapeake Bay retriever: 0.88
# bull mastiff: 0.82
# kuvasz    : 0.74
# capuchin  : 0.82
# pug       : 0.96
# curly-coated retriever: 0.82
# Norwich terrier: 0.62
# flat-coated retriever: 0.9
# hog       : 0.62
# keeshond  : 0.88
# Eskimo dog: 0.42
# Brittany spaniel: 0.88
# standard poodle: 0.88
# Lakeland terrier: 0.78
# snow leopard: 0.9
# Gordon setter: 0.92
# dingo     : 0.82
# standard schnauzer: 0.9
# hamster   : 1.0
# Tibetan terrier: 0.72
# Arctic fox: 0.96
# wire-haired fox terrier: 0.8
# basset    : 0.86
# water buffalo: 0.86
# American black bear: 0.88
# Angora    : 0.98
# bison     : 0.92
# howler monkey: 0.82
# hippopotamus: 0.98
# chow      : 0.9
# giant panda: 0.94
# American Staffordshire terrier: 0.6
# rock beauty: 0.9
# anemone fish: 0.9
# lionfish  : 0.96
# puffer    : 0.88
# sturgeon  : 0.82
# gar       : 0.78
# loggerhead: 0.82
# leatherback turtle: 0.62
# mud turtle: 0.56
# terrapin  : 0.6
# box turtle: 0.9
# banded gecko: 0.82
# common iguana: 0.86
# American chameleon: 0.68
# whiptail  : 0.92
# agama     : 0.82
# frilled lizard: 0.9
# alligator lizard: 0.7
# Gila monster: 0.82
# green lizard: 0.48
# African chameleon: 0.8
# Komodo dragon: 0.94
# triceratops: 0.96
# African crocodile: 0.74
# American alligator: 0.84
# thunder snake: 0.8
# ringneck snake: 0.9
# hognose snake: 0.64
# green snake: 0.66
# king snake: 0.92
# garter snake: 0.96
# water snake: 0.8
# vine snake: 0.68
# night snake: 0.4
# boa constrictor: 0.86
# rock python: 0.48
# Indian cobra: 0.88
# green mamba: 0.76
# sea snake : 0.82
# horned viper: 0.6
# diamondback: 0.8
# sidewinder: 0.34
# European fire salamander: 0.98
# common newt: 0.66
# eft       : 0.76
# spotted salamander: 0.92
# axolotl   : 0.98
# bullfrog  : 0.82
# tree frog : 0.92
# tailed frog: 0.58
# whistle   : 0.78
# wing      : 0.62
# paintbrush: 0.74
# hand blower: 0.72
# oxygen mask: 0.58
# snorkel   : 0.86
# loudspeaker: 0.54
# microphone: 0.7
# screen    : 0.12
# mouse     : 0.48
# electric fan: 0.84
# oil filter: 0.66
# strainer  : 0.66
# space heater: 0.68
# stove     : 0.58
# guillotine: 0.94
# barometer : 0.9
# rule      : 0.82
# odometer  : 0.94
# scale     : 0.72
# analog clock: 0.56
# digital clock: 0.66
# wall clock: 0.66
# hourglass : 0.98
# sundial   : 0.76
# parking meter: 0.92
# stopwatch : 0.58
# digital watch: 0.6
# stethoscope: 0.8
# syringe   : 0.72
# magnetic compass: 0.64
# binoculars: 0.66
# projector : 0.68
# sunglasses: 0.62
# loupe     : 0.42
# radio telescope: 0.9
# bow       : 0.74
# cannon    : 0.92
# assault rifle: 0.46
# rifle     : 0.54
# projectile: 0.34
# computer keyboard: 0.56
# typewriter keyboard: 0.78
# crane     : 0.84
# lighter   : 0.74
# abacus    : 0.88
# cash machine: 0.84
# slide rule: 0.78
# desktop computer: 0.62
# hand-held computer: 0.48
# notebook  : 0.42
# web site  : 0.96
# harvester : 0.86
# thresher  : 0.58
# printer   : 0.58
# slot      : 0.96
# vending machine: 0.92
# sewing machine: 0.86
# joystick  : 0.88
# switch    : 0.74
# hook      : 0.34
# car wheel : 0.42
# paddlewheel: 0.96
# pinwheel  : 0.94
# potter's wheel: 0.9
# gas pump  : 0.9
# carousel  : 0.96
# swing     : 0.78
# reel      : 0.74
# radiator  : 0.84
# puck      : 0.96
# hard disc : 0.86
# sunglass  : 0.08
# pick      : 0.72
# car mirror: 0.96
# solar dish: 0.82
# remote control: 0.84
# disk brake: 0.92
# buckle    : 0.52
# hair slide: 0.44
# knot      : 0.84
# combination lock: 0.76
# padlock   : 0.74
# nail      : 0.66
# safety pin: 0.68
# screw     : 0.92
# muzzle    : 0.78
# seat belt : 0.92
# ski       : 0.76
# candle    : 0.7
# jack-o'-lantern: 0.96
# spotlight : 0.26
# torch     : 0.8
# neck brace: 0.74
# pier      : 0.44
# tripod    : 0.74
# maypole   : 1.0
# mousetrap : 0.86
# spider web: 0.76
# trilobite : 0.98
# harvestman: 0.94
# scorpion  : 0.96
# black and gold garden spider: 0.92
# barn spider: 0.44
# garden spider: 0.6
# black widow: 0.9
# tarantula : 0.96
# wolf spider: 0.8
# tick      : 0.76
# centipede : 0.86
# isopod    : 0.7
# Dungeness crab: 0.86
# rock crab : 0.58
# fiddler crab: 0.72
# king crab : 0.78
# American lobster: 0.84
# spiny lobster: 0.86
# crayfish  : 0.72
# hermit crab: 0.94
# tiger beetle: 0.92
# ladybug   : 0.88
# ground beetle: 0.66
# long-horned beetle: 0.74
# leaf beetle: 0.66
# dung beetle: 0.88
# rhinoceros beetle: 0.88
# weevil    : 0.92
# fly       : 0.88
# bee       : 0.74
# grasshopper: 0.56
# cricket   : 0.68
# walking stick: 0.78
# cockroach : 0.8
# mantis    : 0.82
# cicada    : 0.92
# leafhopper: 0.92
# lacewing  : 0.82
# dragonfly : 0.88
# damselfly : 0.86
# admiral   : 1.0
# ringlet   : 0.98
# monarch   : 0.92
# cabbage butterfly: 0.98
# sulphur butterfly: 0.96
# lycaenid  : 0.9
# jellyfish : 0.92
# sea anemone: 0.68
# brain coral: 0.92
# flatworm  : 0.8
# nematode  : 0.88
# conch     : 0.78
# snail     : 0.86
# slug      : 0.84
# sea slug  : 0.86
# chiton    : 0.82
# sea urchin: 0.84
# sea cucumber: 0.8
# iron      : 0.86
# espresso maker: 0.74
# microwave : 0.6
# Dutch oven: 0.72
# rotisserie: 0.88
# toaster   : 0.74
# waffle iron: 0.84
# vacuum    : 0.84
# dishwasher: 0.64
# refrigerator: 0.88
# washer    : 0.86
# Crock Pot : 0.86
# frying pan: 0.56
# wok       : 0.58
# caldron   : 0.62
# coffeepot : 0.68
# teapot    : 0.7
# spatula   : 0.4
# altar     : 0.64
# triumphal arch: 0.94
# patio     : 0.6
# steel arch bridge: 0.92
# suspension bridge: 0.74
# viaduct   : 0.82
# barn      : 0.96
# greenhouse: 0.88
# palace    : 0.72
# monastery : 0.56
# library   : 0.7
# apiary    : 0.92
# boathouse : 0.94
# church    : 0.68
# mosque    : 0.96
# stupa     : 0.92
# planetarium: 0.96
# restaurant: 0.58
# cinema    : 0.72
# home theater: 0.54
# lumbermill: 0.68
# coil      : 0.74
# obelisk   : 0.88
# totem pole: 0.98
# castle    : 0.82
# prison    : 0.7
# grocery store: 0.6
# bakery    : 0.5
# barbershop: 0.66
# bookshop  : 0.6
# butcher shop: 0.74
# confectionery: 0.54
# shoe shop : 0.96
# tobacco shop: 0.44
# toyshop   : 0.7
# fountain  : 0.9
# cliff dwelling: 0.96
# yurt      : 1.0
# dock      : 0.48
# brass     : 0.92
# megalith  : 0.9
# bannister : 0.84
# breakwater: 0.64
# dam       : 0.84
# chainlink fence: 0.82
# picket fence: 0.9
# worm fence: 0.78
# stone wall: 0.88
# grille    : 0.74
# sliding door: 0.38
# turnstile : 0.88
# mountain tent: 0.86
# scoreboard: 0.86
# honeycomb : 0.68
# plate rack: 0.46
# pedestal  : 0.66
# beacon    : 0.84
# mashed potato: 0.7
# bell pepper: 0.84
# head cabbage: 0.86
# broccoli  : 0.96
# cauliflower: 0.88
# zucchini  : 0.78
# spaghetti squash: 0.84
# acorn squash: 0.88
# butternut squash: 0.82
# cucumber  : 0.74
# artichoke : 0.9
# cardoon   : 0.8
# mushroom  : 0.42
# shower curtain: 0.76
# jean      : 0.78
# carton    : 0.54
# handkerchief: 0.78
# sandal    : 0.72
# ashcan    : 0.58
# safe      : 0.84
# plate     : 0.5
# necklace  : 0.94
# croquet ball: 0.92
# fur coat  : 0.9
# thimble   : 0.74
# pajama    : 0.76
# running shoe: 0.86
# cocktail shaker: 0.64
# chest     : 0.72
# manhole cover: 0.94
# modem     : 0.66
# tub       : 0.32
# tray      : 0.58
# balance beam: 0.94
# bagel     : 0.78
# prayer rug: 0.74
# kimono    : 0.82
# hot pot   : 0.88
# whiskey jug: 0.6
# knee pad  : 0.86
# book jacket: 0.7
# spindle   : 0.98
# ski mask  : 0.82
# beer bottle: 0.8
# crash helmet: 0.88
# bottlecap : 0.72
# tile roof : 0.8
# mask      : 0.64
# maillot   : 0.22
# Petri dish: 0.66
# football helmet: 0.92
# bathing cap: 0.84
# teddy     : 0.82
# holster   : 0.74
# pop bottle: 0.66
# photocopier: 0.94
# vestment  : 0.68
# crossword puzzle: 0.9
# golf ball : 0.94
# trifle    : 0.96
# suit      : 0.72
# water tower: 0.94
# feather boa: 0.88
# cloak     : 0.38
# red wine  : 0.62
# drumstick : 0.66
# shield    : 0.68
# Christmas stocking: 0.96
# hoopskirt : 0.7
# menu      : 0.84
# stage     : 0.64
# bonnet    : 0.7
# meat loaf : 0.66
# baseball  : 0.84
# face powder: 0.72
# scabbard  : 0.82
# sunscreen : 0.5
# beer glass: 0.78
# hen-of-the-woods: 0.84
# guacamole : 0.78
# lampshade : 0.5
# wool      : 0.32
# hay       : 0.9
# bow tie   : 0.86
# mailbag   : 0.66
# water jug : 0.22
# bucket    : 0.66
# dishrag   : 0.96
# soup bowl : 0.5
# eggnog    : 0.52
# mortar    : 0.8
# trench coat: 0.6
# paddle    : 0.62
# chain     : 0.42
# swab      : 0.86
# mixing bowl: 0.84
# potpie    : 0.78
# wine bottle: 0.44
# shoji     : 0.86
# bulletproof vest: 0.6
# drilling platform: 0.92
# binder    : 0.64
# cardigan  : 0.82
# sweatshirt: 0.36
# pot       : 0.86
# birdhouse : 0.94
# hamper    : 0.7
# ping-pong ball: 0.88
# pencil box: 0.78
# pay-phone : 0.9
# consomme  : 0.66
# apron     : 0.8
# punching bag: 0.7
# backpack  : 0.54
# groom     : 0.82
# bearskin  : 0.92
# pencil sharpener: 0.64
# broom     : 0.78
# mosquito net: 0.92
# abaya     : 0.84
# mortarboard: 0.78
# poncho    : 0.74
# crutch    : 0.64
# Polaroid camera: 0.84
# space bar : 0.6
# cup       : 0.44
# racket    : 0.84
# traffic light: 0.86
# quill     : 0.86
# radio     : 0.52
# dough     : 0.42
# cuirass   : 0.56
# military uniform: 0.78
# lipstick  : 0.74
# shower cap: 0.86
# monitor   : 0.26
# oscilloscope: 0.96
# mitten    : 0.82
# brassiere : 0.64
# French loaf: 0.68
# vase      : 0.54
# milk can  : 0.82
# rugby ball: 0.9
# paper towel: 0.8
# earthstar : 1.0
# envelope  : 0.48
# miniskirt : 0.68
# cowboy hat: 0.92
# trolleybus: 1.0
# perfume   : 0.74
# bathtub   : 0.72
# hotdog    : 0.9
# coral fungus: 0.98
# bullet train: 0.98
# pillow    : 0.88
# toilet tissue: 0.52
# cassette  : 0.66
# carpenter's kit: 0.72
# ladle     : 0.4
# stinkhorn : 0.86
# lotion    : 0.58
# hair spray: 0.5
# academic gown: 0.4
# dome      : 0.68
# crate     : 0.6
# wig       : 0.88
# burrito   : 0.88
# pill bottle: 0.8
# chain mail: 0.78
# theater curtain: 0.88
# window shade: 0.64
# barrel    : 0.6
# washbasin : 0.78
# ballpoint : 0.72
# basketball: 1.0
# bath towel: 0.66
# cowboy boot: 0.72
# gown      : 0.68
# window screen: 0.66
# agaric    : 0.86
# cellular telephone: 0.8
# nipple    : 0.9
# barbell   : 0.66
# mailbox   : 0.78
# lab coat  : 0.84
# fire screen: 0.58
# minibus   : 0.88
# packet    : 0.58
# maze      : 0.88
# pole      : 0.5
# horizontal bar: 0.78
# sombrero  : 0.76
# pickelhaube: 0.84
# rain barrel: 0.84
# wallet    : 0.62
# cassette player: 0.3
# comic book: 0.78
# piggy bank: 0.92
# street sign: 0.8
# bell cote : 0.64
# fountain pen: 0.86
# Windsor tie: 0.34
# volleyball: 0.98
# overskirt : 0.24
# sarong    : 0.7
# purse     : 0.5
# bolo tie  : 0.96
# bib       : 0.66
# parachute : 0.98
# sleeping bag: 0.6
# television: 0.72
# swimming trunks: 0.58
# measuring cup: 0.68
# espresso  : 0.66
# pizza     : 0.78
# breastplate: 0.4
# shopping basket: 0.62
# wooden spoon: 0.76
# saltshaker: 0.68
# chocolate sauce: 0.68
# ballplayer: 0.78
# goblet    : 0.6
# gyromitra : 0.98
# stretcher : 0.58
# water bottle: 0.56
# dial telephone: 0.96
# soap dispenser: 0.72
# jersey    : 0.74
# school bus: 0.94
# jigsaw puzzle: 0.96
# plastic bag: 0.5
# reflex camera: 0.78
# diaper    : 0.72
# Band Aid  : 0.76
# ice lolly : 0.82
# velvet    : 0.2
# tennis ball: 0.8
# gasmask   : 0.88
# doormat   : 0.68
# Loafer    : 0.82
# ice cream : 0.74
# pretzel   : 0.84
# quilt     : 0.58
# maillot   : 0.34
# tape player: 0.4
# clog      : 0.64
# iPod      : 0.94
# bolete    : 0.76
# scuba diver: 0.88
# pitcher   : 0.68
# matchstick: 0.7
# bikini    : 0.72
# sock      : 0.68
# CD player : 0.48
# lens cap  : 0.6
# thatch    : 0.94
# vault     : 0.8
# beaker    : 0.6
# bubble    : 0.86
# cheeseburger: 0.94
# parallel bars: 0.7
# flagpole  : 0.9
# coffee mug: 0.6
# rubber eraser: 0.66
# stole     : 0.7
# carbonara : 0.9
# dumbbell  : 0.76

# %%
per_class_acc.mean()
# Out:
# 0.78238

# %%
plt.bar(IMAGENET_DARKNET_CLASS_NAMES[:1000], per_class_acc)
# Out:
# <BarContainer object of 1000 artists>

# %%
evaluator.plot_confusion_matrix(
    confusion_matrix,
    IMAGENET_DARKNET_CLASS_NAMES[:1000],
    "Blues",
    annot=False,
    figsize=(6, 4),
)
