# %%
from pathlib import Path

import albumentations as A
import matplotlib.pyplot as plt
import torch
import torchinfo
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader
from torchlake.common.controller.evaluator import ClassificationEvaluator
from torchlake.common.datasets.imagenet import IMAGENET_DARKNET_CLASS_NAMES
from torchlake.common.utils.platform import get_file_size, get_num_workers
from torchlake.image_classification.models.darknet19 import DarkNet19

# %% [markdown]
# # Setting

# %%
BATCH_SIZE = 32

# %%
artifact_path = Path("../../artifacts/darknet19")
artifact_path.mkdir(exist_ok=True)

data_path = Path("F://imagenet/ILSVRC")

# %%
device = torch.device("cuda:0")

# %% [markdown]
# # data

# %%
IMAGE_SIZE = 224

# %%
# preprocess = A.Compose(
#     [
#         A.HorizontalFlip(),
#         A.ColorJitter(),
#         A.Resize(IMAGE_SIZE, IMAGE_SIZE),
#         ToTensorV2(),
#         A.Normalize(0, 1),
#     ]
# )

# %%
# image folder is enough for training

# dataset = torchvision.datasets.ImageFolder(
#     data_path.joinpath("Data").joinpath("CLS-LOC").joinpath("train").as_posix(),
#     transform=preprocess,
# )

# %%
# train_loader = DataLoader(
#     dataset,
#     batch_size=BATCH_SIZE,
#     shuffle=True,
#     drop_last=True,
#     pin_memory=True,
#     num_workers=get_num_workers(),
# )

# %%
NUM_CLASS = 1000

# %% [markdown]
# # model

# %%
model = DarkNet19(output_size=NUM_CLASS).to(device)

# %%
torchinfo.summary(model)
# Out:
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# DarkNet19                                          --
# ├─Sequential: 1-1                                  --
# │    └─Conv2dNormActivation: 2-1                   --
# │    │    └─Conv2d: 3-1                            864
# │    │    └─BatchNorm2d: 3-2                       64
# │    │    └─LeakyReLU: 3-3                         --
# │    └─MaxPool2d: 2-2                              --
# │    └─Conv2dNormActivation: 2-3                   --
# │    │    └─Conv2d: 3-4                            18,432
# │    │    └─BatchNorm2d: 3-5                       128
# │    │    └─LeakyReLU: 3-6                         --
# │    └─MaxPool2d: 2-4                              --
# ├─Sequential: 1-2                                  --
# │    └─BottleNeck: 2-5                             --
# │    │    └─Sequential: 3-7                        156,288
# │    └─MaxPool2d: 2-6                              --
# │    └─BottleNeck: 2-7                             --
# │    │    └─Sequential: 3-8                        623,872
# │    └─MaxPool2d: 2-8                              --
# │    └─BottleNeck: 2-9                             --
# │    │    └─Sequential: 3-9                        3,805,184
# │    └─MaxPool2d: 2-10                             --
# │    └─BottleNeck: 2-11                            --
# │    │    └─Sequential: 3-10                       15,212,544
# ├─Sequential: 1-3                                  --
# │    └─FlattenFeature: 2-12                        --
# │    │    └─Sequential: 3-11                       --
# │    └─Linear: 2-13                                1,025,000
# ===========================================================================
# Total params: 20,842,376
# Trainable params: 20,842,376
# Non-trainable params: 0
# ===========================================================================

# %%
model_path = artifact_path.joinpath("darknet19.pth")

# %% [markdown]
# we will show how to convert from darknet weights, which is already trained on ImageNet :D

# %%
FORCE_INVALIDATE = False

weights_path = artifact_path.joinpath("darknet19.weights")

if (weights_path.exists() and not model_path.exists()) or FORCE_INVALIDATE:
    from torchlake.image_classification.helpers.convertor_darknet19 import DarkNet19Convertor
    convertor = DarkNet19Convertor()
    remaining_bits = convertor.run(weights_path, model)
    
    assert remaining_bits == 0, "still bits not transferred"
    
    torch.save(model.state_dict(), model_path)
# Out:
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# Conv2dNormActivation
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# Conv2dNormActivation
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting bottleneck
# start converting bn
# finish converting bn
# start converting conv
# finish converting conv
# finish converting bottleneck
# start converting conv
# finish converting conv
# conv / linear
# remaning: 0

# %%
model.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
test_preprocess = A.Compose(
    [
        A.Resize(IMAGE_SIZE, IMAGE_SIZE),
        A.Normalize(0, 1),
        ToTensorV2(),
    ]
)

# %%
# debug here
from torchlake.common.utils.image import load_image
img = load_image("F://imagenet/ILSVRC/Data/CLS-LOC/test/ILSVRC2012_test_00000002.JPEG", is_numpy=True)
img = test_preprocess(image=img)["image"]
img = img.unsqueeze_(0).cuda()

# %%
model.eval()
with torch.no_grad():
    print(IMAGENET_DARKNET_CLASS_NAMES[model(img).argmax(1)])
# Out:
# magpie

# %% [markdown]
# # inference

# %%
VAL_IMAGE_SIZE = 256

# %%
model_path = artifact_path.joinpath("darknet19.pth")

# %%
get_file_size(model_path)
# Out:
# '79.6MiB'

# %%
model.load_state_dict(torch.load(model_path.as_posix()))
# Out:
# <All keys matched successfully>

# %%
test_preprocess = A.Compose(
    [
        A.Resize(VAL_IMAGE_SIZE, VAL_IMAGE_SIZE),
        A.Normalize(0, 1),
        ToTensorV2(),
    ]
)

# %%
from torchlake.common.datasets.imagenet import ImageNetFromXML

# %%
test_dataset = ImageNetFromXML(
    data_path,
    label_encode="darknet",
    transform=test_preprocess,
)

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    pin_memory=True,
    num_workers=get_num_workers(),
)

# %%
evaluator = ClassificationEvaluator(NUM_CLASS, device)

# %%
confusion_matrix = evaluator.run(test_loader, model)
# Out:
# 100%|██████████| 1563/1563 [07:52<00:00,  3.30it/s]
# [[26  0  0 ...  0  0  0]
#  [ 0 38  0 ...  0  0  0]
#  [ 0  0 34 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 29  0  0]
#  [ 0  0  0 ...  0 42  0]
#  [ 0  0  0 ...  0  0 27]]

# %%
per_class_acc = evaluator.get_per_class_accuracy(confusion_matrix)
evaluator.show_per_class_accuracy(IMAGENET_DARKNET_CLASS_NAMES[:1000], per_class_acc)
# Out:
# kit fox   : 0.52
# English setter: 0.76
# Siberian husky: 0.68
# Australian terrier: 0.58
# English springer: 0.88
# grey whale: 0.9
# lesser panda: 0.94
# Egyptian cat: 0.54
# ibex      : 0.92
# Persian cat: 0.86
# cougar    : 0.92
# gazelle   : 0.58
# porcupine : 0.88
# sea lion  : 0.8
# malamute  : 0.72
# badger    : 0.86
# Great Dane: 0.68
# Walker hound: 0.7
# Welsh springer spaniel: 0.92
# whippet   : 0.7
# Scottish deerhound: 0.8
# killer whale: 0.96
# mink      : 0.68
# African elephant: 0.64
# Weimaraner: 0.9
# soft-coated wheaten terrier: 0.62
# Dandie Dinmont: 0.8
# red wolf  : 0.62
# Old English sheepdog: 0.88
# jaguar    : 0.72
# otterhound: 0.62
# bloodhound: 0.54
# Airedale  : 0.84
# hyena     : 0.88
# meerkat   : 0.86
# giant schnauzer: 0.7
# titi      : 0.58
# three-toed sloth: 0.9
# sorrel    : 0.96
# black-footed ferret: 0.68
# dalmatian : 0.94
# black-and-tan coonhound: 0.52
# papillon  : 0.9
# skunk     : 0.94
# Staffordshire bullterrier: 0.66
# Mexican hairless: 0.78
# Bouvier des Flandres: 0.72
# weasel    : 0.42
# miniature poodle: 0.36
# Cardigan  : 0.54
# malinois  : 0.84
# bighorn   : 0.7
# fox squirrel: 0.78
# colobus   : 0.88
# tiger cat : 0.26
# Lhasa     : 0.62
# impala    : 0.76
# coyote    : 0.64
# Yorkshire terrier: 0.46
# Newfoundland: 0.76
# brown bear: 0.94
# red fox   : 0.62
# Norwegian elkhound: 0.78
# Rottweiler: 0.82
# hartebeest: 0.94
# Saluki    : 0.74
# grey fox  : 0.64
# schipperke: 0.7
# Pekinese  : 0.76
# Brabancon griffon: 0.84
# West Highland white terrier: 0.86
# Sealyham terrier: 0.76
# guenon    : 0.8
# mongoose  : 0.68
# indri     : 0.82
# tiger     : 0.92
# Irish wolfhound: 0.52
# wild boar : 0.78
# EntleBucher: 0.58
# zebra     : 0.94
# ram       : 0.7
# French bulldog: 0.78
# orangutan : 0.84
# basenji   : 0.88
# leopard   : 0.84
# Bernese mountain dog: 0.86
# Maltese dog: 0.74
# Norfolk terrier: 0.66
# toy terrier: 0.56
# vizsla    : 0.76
# cairn     : 0.72
# squirrel monkey: 0.76
# groenendael: 0.76
# clumber   : 0.82
# Siamese cat: 0.92
# chimpanzee: 0.78
# komondor  : 0.86
# Afghan hound: 0.84
# Japanese spaniel: 0.68
# proboscis monkey: 1.0
# guinea pig: 0.76
# white wolf: 0.84
# ice bear  : 0.88
# gorilla   : 0.86
# borzoi    : 0.88
# toy poodle: 0.38
# Kerry blue terrier: 0.72
# ox        : 0.46
# Scotch terrier: 0.76
# Tibetan mastiff: 0.9
# spider monkey: 0.4
# Doberman  : 0.76
# Boston bull: 0.76
# Greater Swiss Mountain dog: 0.68
# Appenzeller: 0.32
# Shih-Tzu  : 0.72
# Irish water spaniel: 0.78
# Pomeranian: 0.94
# Bedlington terrier: 0.76
# warthog   : 0.86
# Arabian camel: 0.96
# siamang   : 0.7
# miniature schnauzer: 0.64
# collie    : 0.58
# golden retriever: 0.78
# Irish terrier: 0.7
# affenpinscher: 0.74
# Border collie: 0.66
# hare      : 0.84
# boxer     : 0.74
# silky terrier: 0.64
# beagle    : 0.64
# Leonberg  : 0.98
# German short-haired pointer: 0.76
# patas     : 0.62
# dhole     : 0.84
# baboon    : 0.86
# macaque   : 0.68
# Chesapeake Bay retriever: 0.72
# bull mastiff: 0.76
# kuvasz    : 0.62
# capuchin  : 0.72
# pug       : 0.86
# curly-coated retriever: 0.7
# Norwich terrier: 0.64
# flat-coated retriever: 0.72
# hog       : 0.52
# keeshond  : 0.86
# Eskimo dog: 0.38
# Brittany spaniel: 0.84
# standard poodle: 0.8
# Lakeland terrier: 0.64
# snow leopard: 0.88
# Gordon setter: 0.9
# dingo     : 0.76
# standard schnauzer: 0.78
# hamster   : 1.0
# Tibetan terrier: 0.62
# Arctic fox: 0.88
# wire-haired fox terrier: 0.7
# basset    : 0.84
# water buffalo: 0.8
# American black bear: 0.86
# Angora    : 0.94
# bison     : 0.92
# howler monkey: 0.84
# hippopotamus: 0.84
# chow      : 0.84
# giant panda: 0.9
# American Staffordshire terrier: 0.48
# Shetland sheepdog: 0.66
# Great Pyrenees: 0.76
# Chihuahua : 0.52
# tabby     : 0.56
# marmoset  : 0.7
# Labrador retriever: 0.68
# Saint Bernard: 0.92
# armadillo : 0.88
# Samoyed   : 0.94
# bluetick  : 0.78
# redbone   : 0.6
# polecat   : 0.38
# marmot    : 0.9
# kelpie    : 0.58
# gibbon    : 0.78
# llama     : 0.84
# miniature pinscher: 0.56
# wood rabbit: 0.78
# Italian greyhound: 0.82
# lion      : 0.86
# cocker spaniel: 0.64
# Irish setter: 0.74
# dugong    : 0.82
# Indian elephant: 0.5
# beaver    : 0.82
# Sussex spaniel: 0.62
# Pembroke  : 0.84
# Blenheim spaniel: 0.9
# Madagascar cat: 0.58
# Rhodesian ridgeback: 0.64
# lynx      : 0.68
# African hunting dog: 1.0
# langur    : 0.48
# Ibizan hound: 0.68
# timber wolf: 0.72
# cheetah   : 0.96
# English foxhound: 0.14
# briard    : 0.52
# sloth bear: 0.7
# Border terrier: 0.82
# German shepherd: 0.76
# otter     : 0.72
# koala     : 0.88
# tusker    : 0.56
# echidna   : 0.98
# wallaby   : 0.82
# platypus  : 0.74
# wombat    : 0.7
# revolver  : 0.86
# umbrella  : 0.58
# schooner  : 0.78
# soccer ball: 0.88
# accordion : 0.78
# ant       : 0.66
# starfish  : 0.84
# chambered nautilus: 0.76
# grand piano: 0.64
# laptop    : 0.18
# strawberry: 0.6
# airliner  : 0.92
# warplane  : 0.74
# airship   : 0.9
# balloon   : 0.94
# space shuttle: 0.86
# fireboat  : 0.94
# gondola   : 0.98
# speedboat : 0.92
# lifeboat  : 0.96
# canoe     : 0.88
# yawl      : 0.76
# catamaran : 0.62
# trimaran  : 0.7
# container ship: 0.86
# liner     : 0.9
# pirate    : 0.82
# aircraft carrier: 0.78
# submarine : 0.82
# wreck     : 0.8
# half track: 0.72
# tank      : 0.78
# missile   : 0.44
# bobsled   : 0.92
# dogsled   : 0.92
# bicycle-built-for-two: 0.82
# mountain bike: 0.82
# freight car: 1.0
# passenger car: 0.56
# barrow    : 0.78
# shopping cart: 0.78
# motor scooter: 0.82
# forklift  : 0.82
# electric locomotive: 0.86
# steam locomotive: 0.88
# amphibian : 0.64
# ambulance : 0.92
# beach wagon: 0.56
# cab       : 0.72
# convertible: 0.66
# jeep      : 0.76
# limousine : 0.66
# minivan   : 0.54
# Model T   : 0.92
# racer     : 0.76
# sports car: 0.54
# go-kart   : 0.84
# golfcart  : 0.78
# moped     : 0.66
# snowplow  : 0.88
# fire engine: 0.82
# garbage truck: 0.88
# pickup    : 0.7
# tow truck : 0.6
# trailer truck: 0.74
# moving van: 0.46
# police van: 0.82
# recreational vehicle: 0.84
# streetcar : 0.88
# snowmobile: 0.88
# tractor   : 0.76
# mobile home: 0.64
# tricycle  : 0.84
# unicycle  : 0.78
# horse cart: 0.82
# jinrikisha: 0.9
# oxcart    : 0.68
# bassinet  : 0.72
# cradle    : 0.42
# crib      : 0.78
# four-poster: 0.8
# bookcase  : 0.68
# china cabinet: 0.82
# medicine chest: 0.68
# chiffonier: 0.18
# table lamp: 0.68
# file      : 0.84
# park bench: 0.74
# barber chair: 0.74
# throne    : 0.64
# folding chair: 0.76
# rocking chair: 0.68
# studio couch: 0.74
# toilet seat: 0.72
# desk      : 0.52
# pool table: 0.84
# dining table: 0.84
# entertainment center: 0.88
# wardrobe  : 0.68
# Granny Smith: 0.86
# orange    : 0.72
# lemon     : 0.8
# fig       : 0.78
# pineapple : 0.82
# banana    : 0.8
# jackfruit : 0.94
# custard apple: 0.86
# pomegranate: 0.84
# acorn     : 0.92
# hip       : 0.98
# ear       : 0.5
# rapeseed  : 0.94
# corn      : 0.46
# buckeye   : 0.88
# organ     : 0.84
# upright   : 0.74
# chime     : 0.64
# drum      : 0.42
# gong      : 0.56
# maraca    : 0.62
# marimba   : 0.88
# steel drum: 0.84
# banjo     : 0.86
# cello     : 0.8
# violin    : 0.62
# harp      : 0.86
# acoustic guitar: 0.44
# electric guitar: 0.66
# cornet    : 0.56
# French horn: 0.74
# trombone  : 0.58
# harmonica : 0.56
# ocarina   : 0.84
# panpipe   : 0.76
# bassoon   : 0.74
# oboe      : 0.6
# sax       : 0.7
# flute     : 0.38
# daisy     : 0.96
# yellow lady's slipper: 1.0
# cliff     : 0.78
# valley    : 0.78
# alp       : 0.68
# volcano   : 0.82
# promontory: 0.5
# sandbar   : 0.64
# coral reef: 0.78
# lakeside  : 0.64
# seashore  : 0.46
# geyser    : 0.92
# hatchet   : 0.54
# cleaver   : 0.42
# letter opener: 0.24
# plane     : 0.86
# power drill: 0.44
# lawn mower: 0.84
# hammer    : 0.62
# corkscrew : 0.84
# can opener: 0.72
# plunger   : 0.5
# screwdriver: 0.36
# shovel    : 0.7
# plow      : 0.72
# chain saw : 0.88
# cock      : 0.82
# hen       : 0.86
# ostrich   : 0.98
# brambling : 0.72
# goldfinch : 0.94
# house finch: 0.94
# junco     : 0.96
# indigo bunting: 0.9
# robin     : 0.96
# bulbul    : 0.84
# jay       : 0.9
# magpie    : 0.9
# chickadee : 0.98
# water ouzel: 0.84
# kite      : 0.78
# bald eagle: 0.9
# vulture   : 0.98
# great grey owl: 0.98
# black grouse: 0.84
# ptarmigan : 0.78
# ruffed grouse: 0.86
# prairie chicken: 0.86
# peacock   : 0.88
# quail     : 0.9
# partridge : 0.68
# African grey: 0.92
# macaw     : 0.96
# sulphur-crested cockatoo: 0.88
# lorikeet  : 0.94
# coucal    : 0.9
# bee eater : 0.96
# hornbill  : 0.88
# hummingbird: 0.92
# jacamar   : 0.92
# toucan    : 0.94
# drake     : 0.86
# red-breasted merganser: 0.86
# goose     : 0.7
# black swan: 0.96
# white stork: 0.88
# black stork: 0.76
# spoonbill : 0.96
# flamingo  : 0.92
# American egret: 0.9
# little blue heron: 0.92
# bittern   : 0.84
# crane     : 0.72
# limpkin   : 0.98
# American coot: 0.84
# bustard   : 0.94
# ruddy turnstone: 0.98
# red-backed sandpiper: 0.82
# redshank  : 0.92
# dowitcher : 0.9
# oystercatcher: 0.9
# European gallinule: 0.96
# pelican   : 0.9
# king penguin: 0.9
# albatross : 0.92
# great white shark: 0.86
# tiger shark: 0.78
# hammerhead: 0.82
# electric ray: 0.72
# stingray  : 0.78
# barracouta: 0.72
# coho      : 0.82
# tench     : 0.84
# goldfish  : 0.9
# eel       : 0.56
# rock beauty: 0.92
# anemone fish: 0.76
# lionfish  : 0.92
# puffer    : 0.84
# sturgeon  : 0.7
# gar       : 0.56
# loggerhead: 0.72
# leatherback turtle: 0.56
# mud turtle: 0.58
# terrapin  : 0.5
# box turtle: 0.86
# banded gecko: 0.72
# common iguana: 0.8
# American chameleon: 0.46
# whiptail  : 0.72
# agama     : 0.76
# frilled lizard: 0.84
# alligator lizard: 0.54
# Gila monster: 0.72
# green lizard: 0.58
# African chameleon: 0.76
# Komodo dragon: 0.86
# triceratops: 0.9
# African crocodile: 0.56
# American alligator: 0.76
# thunder snake: 0.7
# ringneck snake: 0.84
# hognose snake: 0.5
# green snake: 0.62
# king snake: 0.76
# garter snake: 0.82
# water snake: 0.58
# vine snake: 0.66
# night snake: 0.28
# boa constrictor: 0.8
# rock python: 0.46
# Indian cobra: 0.8
# green mamba: 0.62
# sea snake : 0.66
# horned viper: 0.54
# diamondback: 0.66
# sidewinder: 0.22
# European fire salamander: 0.9
# common newt: 0.52
# eft       : 0.74
# spotted salamander: 0.84
# axolotl   : 0.78
# bullfrog  : 0.82
# tree frog : 0.82
# tailed frog: 0.38
# whistle   : 0.76
# wing      : 0.62
# paintbrush: 0.72
# hand blower: 0.62
# oxygen mask: 0.52
# snorkel   : 0.82
# loudspeaker: 0.56
# microphone: 0.44
# screen    : 0.12
# mouse     : 0.44
# electric fan: 0.76
# oil filter: 0.66
# strainer  : 0.62
# space heater: 0.6
# stove     : 0.48
# guillotine: 0.84
# barometer : 0.74
# rule      : 0.74
# odometer  : 0.96
# scale     : 0.66
# analog clock: 0.54
# digital clock: 0.6
# wall clock: 0.6
# hourglass : 0.96
# sundial   : 0.58
# parking meter: 0.86
# stopwatch : 0.54
# digital watch: 0.6
# stethoscope: 0.56
# syringe   : 0.62
# magnetic compass: 0.6
# binoculars: 0.56
# projector : 0.58
# sunglasses: 0.34
# loupe     : 0.28
# radio telescope: 0.9
# bow       : 0.66
# cannon    : 0.86
# assault rifle: 0.48
# rifle     : 0.4
# projectile: 0.3
# computer keyboard: 0.7
# typewriter keyboard: 0.7
# crane     : 0.68
# lighter   : 0.6
# abacus    : 0.8
# cash machine: 0.82
# slide rule: 0.64
# desktop computer: 0.58
# hand-held computer: 0.48
# notebook  : 0.3
# web site  : 0.96
# harvester : 0.76
# thresher  : 0.54
# printer   : 0.48
# slot      : 0.94
# vending machine: 0.98
# sewing machine: 0.76
# joystick  : 0.68
# switch    : 0.56
# hook      : 0.28
# car wheel : 0.4
# paddlewheel: 0.94
# pinwheel  : 0.76
# potter's wheel: 0.9
# gas pump  : 0.8
# carousel  : 0.98
# swing     : 0.76
# reel      : 0.64
# radiator  : 0.72
# puck      : 0.88
# hard disc : 0.76
# sunglass  : 0.08
# pick      : 0.74
# car mirror: 0.92
# solar dish: 0.7
# remote control: 0.76
# disk brake: 0.84
# buckle    : 0.46
# hair slide: 0.42
# knot      : 0.74
# combination lock: 0.7
# padlock   : 0.72
# nail      : 0.6
# safety pin: 0.5
# screw     : 0.88
# muzzle    : 0.42
# seat belt : 0.84
# ski       : 0.64
# candle    : 0.62
# jack-o'-lantern: 0.94
# spotlight : 0.3
# torch     : 0.66
# neck brace: 0.6
# pier      : 0.56
# tripod    : 0.68
# maypole   : 0.98
# mousetrap : 0.76
# spider web: 0.7
# trilobite : 0.92
# harvestman: 0.78
# scorpion  : 0.82
# black and gold garden spider: 0.76
# barn spider: 0.4
# garden spider: 0.64
# black widow: 0.86
# tarantula : 0.84
# wolf spider: 0.74
# tick      : 0.74
# centipede : 0.8
# isopod    : 0.58
# Dungeness crab: 0.88
# rock crab : 0.54
# fiddler crab: 0.62
# king crab : 0.72
# American lobster: 0.74
# spiny lobster: 0.76
# crayfish  : 0.54
# hermit crab: 0.8
# tiger beetle: 0.88
# ladybug   : 0.82
# ground beetle: 0.62
# long-horned beetle: 0.62
# leaf beetle: 0.64
# dung beetle: 0.82
# rhinoceros beetle: 0.9
# weevil    : 0.82
# fly       : 0.76
# bee       : 0.72
# grasshopper: 0.54
# cricket   : 0.58
# walking stick: 0.64
# cockroach : 0.72
# mantis    : 0.66
# cicada    : 0.84
# leafhopper: 0.88
# lacewing  : 0.84
# dragonfly : 0.84
# damselfly : 0.78
# admiral   : 0.96
# ringlet   : 0.92
# monarch   : 0.92
# cabbage butterfly: 0.94
# sulphur butterfly: 0.9
# lycaenid  : 0.86
# jellyfish : 0.82
# sea anemone: 0.66
# brain coral: 0.8
# flatworm  : 0.7
# nematode  : 0.9
# conch     : 0.68
# snail     : 0.8
# slug      : 0.78
# sea slug  : 0.88
# chiton    : 0.74
# sea urchin: 0.84
# sea cucumber: 0.74
# iron      : 0.82
# espresso maker: 0.72
# microwave : 0.5
# Dutch oven: 0.66
# rotisserie: 0.84
# toaster   : 0.68
# waffle iron: 0.7
# vacuum    : 0.8
# dishwasher: 0.56
# refrigerator: 0.8
# washer    : 0.84
# Crock Pot : 0.86
# frying pan: 0.44
# wok       : 0.42
# caldron   : 0.46
# coffeepot : 0.56
# teapot    : 0.74
# spatula   : 0.36
# altar     : 0.7
# triumphal arch: 0.94
# patio     : 0.52
# steel arch bridge: 0.72
# suspension bridge: 0.62
# viaduct   : 0.84
# barn      : 0.94
# greenhouse: 0.88
# palace    : 0.78
# monastery : 0.46
# library   : 0.58
# apiary    : 0.9
# boathouse : 0.84
# church    : 0.66
# mosque    : 0.94
# stupa     : 0.88
# planetarium: 0.82
# restaurant: 0.48
# cinema    : 0.64
# home theater: 0.62
# lumbermill: 0.74
# coil      : 0.62
# obelisk   : 0.78
# totem pole: 0.9
# castle    : 0.84
# prison    : 0.76
# grocery store: 0.6
# bakery    : 0.38
# barbershop: 0.68
# bookshop  : 0.6
# butcher shop: 0.82
# confectionery: 0.48
# shoe shop : 0.82
# tobacco shop: 0.38
# toyshop   : 0.68
# fountain  : 0.86
# cliff dwelling: 0.86
# yurt      : 0.96
# dock      : 0.5
# brass     : 0.82
# megalith  : 0.86
# bannister : 0.7
# breakwater: 0.72
# dam       : 0.78
# chainlink fence: 0.72
# picket fence: 0.84
# worm fence: 0.72
# stone wall: 0.78
# grille    : 0.76
# sliding door: 0.38
# turnstile : 0.76
# mountain tent: 0.86
# scoreboard: 0.92
# honeycomb : 0.58
# plate rack: 0.5
# pedestal  : 0.66
# beacon    : 0.84
# mashed potato: 0.66
# bell pepper: 0.82
# head cabbage: 0.88
# broccoli  : 0.92
# cauliflower: 0.82
# zucchini  : 0.7
# spaghetti squash: 0.78
# acorn squash: 0.84
# butternut squash: 0.7
# cucumber  : 0.7
# artichoke : 0.8
# cardoon   : 0.88
# mushroom  : 0.36
# shower curtain: 0.66
# jean      : 0.66
# carton    : 0.5
# handkerchief: 0.76
# sandal    : 0.66
# ashcan    : 0.52
# safe      : 0.82
# plate     : 0.52
# necklace  : 0.94
# croquet ball: 0.86
# fur coat  : 0.86
# thimble   : 0.6
# pajama    : 0.66
# running shoe: 0.84
# cocktail shaker: 0.54
# chest     : 0.7
# manhole cover: 0.94
# modem     : 0.62
# tub       : 0.36
# tray      : 0.56
# balance beam: 0.84
# bagel     : 0.68
# prayer rug: 0.7
# kimono    : 0.8
# hot pot   : 0.72
# whiskey jug: 0.56
# knee pad  : 0.8
# book jacket: 0.7
# spindle   : 0.84
# ski mask  : 0.78
# beer bottle: 0.74
# crash helmet: 0.8
# bottlecap : 0.66
# tile roof : 0.74
# mask      : 0.56
# maillot   : 0.22
# Petri dish: 0.56
# football helmet: 0.82
# bathing cap: 0.6
# teddy     : 0.74
# holster   : 0.7
# pop bottle: 0.7
# photocopier: 0.9
# vestment  : 0.52
# crossword puzzle: 0.84
# golf ball : 0.76
# trifle    : 0.94
# suit      : 0.44
# water tower: 0.94
# feather boa: 0.8
# cloak     : 0.34
# red wine  : 0.56
# drumstick : 0.48
# shield    : 0.54
# Christmas stocking: 0.86
# hoopskirt : 0.66
# menu      : 0.84
# stage     : 0.74
# bonnet    : 0.62
# meat loaf : 0.58
# baseball  : 0.7
# face powder: 0.74
# scabbard  : 0.78
# sunscreen : 0.34
# beer glass: 0.66
# hen-of-the-woods: 0.8
# guacamole : 0.7
# lampshade : 0.5
# wool      : 0.34
# hay       : 0.8
# bow tie   : 0.7
# mailbag   : 0.56
# water jug : 0.28
# bucket    : 0.62
# dishrag   : 0.86
# soup bowl : 0.58
# eggnog    : 0.4
# mortar    : 0.76
# trench coat: 0.44
# paddle    : 0.66
# chain     : 0.26
# swab      : 0.84
# mixing bowl: 0.8
# potpie    : 0.6
# wine bottle: 0.46
# shoji     : 0.74
# bulletproof vest: 0.46
# drilling platform: 0.86
# binder    : 0.64
# cardigan  : 0.76
# sweatshirt: 0.38
# pot       : 0.88
# birdhouse : 0.8
# hamper    : 0.74
# ping-pong ball: 0.84
# pencil box: 0.7
# pay-phone : 0.68
# consomme  : 0.52
# apron     : 0.72
# punching bag: 0.72
# backpack  : 0.42
# groom     : 0.76
# bearskin  : 0.88
# pencil sharpener: 0.46
# broom     : 0.68
# mosquito net: 0.86
# abaya     : 0.82
# mortarboard: 0.64
# poncho    : 0.7
# crutch    : 0.5
# Polaroid camera: 0.78
# space bar : 0.36
# cup       : 0.36
# racket    : 0.78
# traffic light: 0.86
# quill     : 0.68
# radio     : 0.52
# dough     : 0.34
# cuirass   : 0.34
# military uniform: 0.64
# lipstick  : 0.64
# shower cap: 0.7
# monitor   : 0.28
# oscilloscope: 0.9
# mitten    : 0.74
# brassiere : 0.56
# French loaf: 0.54
# vase      : 0.52
# milk can  : 0.7
# rugby ball: 0.84
# paper towel: 0.62
# earthstar : 1.0
# envelope  : 0.48
# miniskirt : 0.56
# cowboy hat: 0.72
# trolleybus: 0.98
# perfume   : 0.72
# bathtub   : 0.44
# hotdog    : 0.82
# coral fungus: 0.96
# bullet train: 0.96
# pillow    : 0.82
# toilet tissue: 0.48
# cassette  : 0.6
# carpenter's kit: 0.58
# ladle     : 0.34
# stinkhorn : 0.82
# lotion    : 0.52
# hair spray: 0.48
# academic gown: 0.34
# dome      : 0.68
# crate     : 0.54
# wig       : 0.82
# burrito   : 0.88
# pill bottle: 0.7
# chain mail: 0.62
# theater curtain: 0.76
# window shade: 0.66
# barrel    : 0.62
# washbasin : 0.88
# ballpoint : 0.46
# basketball: 0.9
# bath towel: 0.62
# cowboy boot: 0.72
# gown      : 0.54
# window screen: 0.72
# agaric    : 0.86
# cellular telephone: 0.78
# nipple    : 0.7
# barbell   : 0.64
# mailbox   : 0.72
# lab coat  : 0.8
# fire screen: 0.54
# minibus   : 0.8
# packet    : 0.54
# maze      : 0.84
# pole      : 0.4
# horizontal bar: 0.7
# sombrero  : 0.6
# pickelhaube: 0.78
# rain barrel: 0.78
# wallet    : 0.52
# cassette player: 0.24
# comic book: 0.6
# piggy bank: 0.88
# street sign: 0.74
# bell cote : 0.56
# fountain pen: 0.7
# Windsor tie: 0.26
# volleyball: 0.9
# overskirt : 0.24
# sarong    : 0.62
# purse     : 0.44
# bolo tie  : 0.82
# bib       : 0.62
# parachute : 0.9
# sleeping bag: 0.58
# television: 0.58
# swimming trunks: 0.44
# measuring cup: 0.58
# espresso  : 0.64
# pizza     : 0.82
# breastplate: 0.34
# shopping basket: 0.52
# wooden spoon: 0.62
# saltshaker: 0.62
# chocolate sauce: 0.48
# ballplayer: 0.82
# goblet    : 0.64
# gyromitra : 0.92
# stretcher : 0.52
# water bottle: 0.48
# dial telephone: 0.9
# soap dispenser: 0.6
# jersey    : 0.86
# school bus: 0.88
# jigsaw puzzle: 0.84
# plastic bag: 0.44
# reflex camera: 0.66
# diaper    : 0.6
# Band Aid  : 0.66
# ice lolly : 0.68
# velvet    : 0.18
# tennis ball: 0.82
# gasmask   : 0.74
# doormat   : 0.58
# Loafer    : 0.8
# ice cream : 0.64
# pretzel   : 0.74
# quilt     : 0.64
# maillot   : 0.24
# tape player: 0.42
# clog      : 0.6
# iPod      : 0.76
# bolete    : 0.7
# scuba diver: 0.86
# pitcher   : 0.52
# matchstick: 0.64
# bikini    : 0.56
# sock      : 0.68
# CD player : 0.46
# lens cap  : 0.46
# thatch    : 0.86
# vault     : 0.78
# beaker    : 0.52
# bubble    : 0.8
# cheeseburger: 0.92
# parallel bars: 0.7
# flagpole  : 0.72
# coffee mug: 0.46
# rubber eraser: 0.5
# stole     : 0.58
# carbonara : 0.84
# dumbbell  : 0.54

# %%
per_class_acc.mean()
# Out:
# 0.71548

# %%
plt.bar(IMAGENET_DARKNET_CLASS_NAMES[:1000], per_class_acc)
# Out:
# <BarContainer object of 1000 artists>

# %%
evaluator.plot_confusion_matrix(
    confusion_matrix,
    IMAGENET_DARKNET_CLASS_NAMES[:1000],
    "Blues",
    annot=False,
    figsize=(6, 4),
)
