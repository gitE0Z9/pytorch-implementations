# %%
from pathlib import Path

import matplotlib.pyplot as plt
import torch
import torchinfo
from torch.utils.data import DataLoader
from torchlake.common.constants import IMAGENET_MEAN, IMAGENET_STD
from torchlake.common.controller.trainer import ClassificationTrainer
from torchlake.common.controller.evaluator import ClassificationEvaluator
from torchlake.common.utils.platform import get_num_workers, get_file_size
from torchlake.image_classification.models.inceptionv4 import InceptionResNetV2
from torchvision import transforms
from torchvision.datasets import GTSRB

# %% [markdown]
# # Setting

# %%
IMAGE_SIZE = 299
BATCH_SIZE = 32

# %%
artifact_path = Path("../../artifacts/inceptionv4")
artifact_path.mkdir(exist_ok=True)

data_path = Path("../../data/gtsrb")

# %%
DEVICE = torch.device("cuda:0")

# %% [markdown]
# # data

# %%
preprocess = transforms.Compose(
    [
        transforms.RandomHorizontalFlip(),
        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
    ]
)

# %%
train_dataset = GTSRB(
    data_path.as_posix(),
    split="train",
    transform=preprocess,
    download=True,
)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=True,
    pin_memory=True,
    num_workers=get_num_workers(),
)

# %%
NUM_CLASS = 43

# %%
len(train_dataset)
# Out:
# 26640

# %%
import random
from torchlake.common.utils.convert import img_tensor_to_np

demo_img, demo_label = random.choice(train_dataset)
print(demo_label)
plt.imshow((img_tensor_to_np(demo_img) * IMAGENET_STD + IMAGENET_MEAN).clip(0, 1))
# Out:
# 13

# %% [markdown]
# # model

# %%
model = InceptionResNetV2(output_size=NUM_CLASS, dropout_prob=0).to(DEVICE)

# %%
torchinfo.summary(model)
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                                                      Param #
# ====================================================================================================
# InceptionResNetV2                                                           --
# ├─Sequential: 1-1                                                           --
# │    └─Conv2dNormActivation: 2-1                                            --
# │    │    └─Conv2d: 3-1                                                     864
# │    │    └─BatchNorm2d: 3-2                                                64
# │    │    └─ReLU: 3-3                                                       --
# │    └─Conv2dNormActivation: 2-2                                            --
# │    │    └─Conv2d: 3-4                                                     9,216
# │    │    └─BatchNorm2d: 3-5                                                64
# │    │    └─ReLU: 3-6                                                       --
# │    └─Conv2dNormActivation: 2-3                                            --
# │    │    └─Conv2d: 3-7                                                     18,432
# │    │    └─BatchNorm2d: 3-8                                                128
# │    │    └─ReLU: 3-9                                                       --
# │    └─InceptionBlockV3: 2-4                                                --
# │    │    └─ModuleList: 3-10                                                55,488
# │    └─InceptionBlockV3: 2-5                                                --
# │    │    └─ModuleList: 3-11                                                189,312
# │    └─InceptionBlockV3: 2-6                                                --
# │    │    └─ModuleList: 3-12                                                332,160
# ├─Sequential: 1-2                                                           --
# │    └─ResBlock: 2-7                                                        --
# │    │    └─ReLU: 3-13                                                      --
# │    │    └─Sequential: 3-14                                                137,952
# │    │    └─Identity: 3-15                                                  --
# │    └─ResBlock: 2-8                                                        --
# │    │    └─ReLU: 3-16                                                      --
# │    │    └─Sequential: 3-17                                                137,952
# │    │    └─Identity: 3-18                                                  --
# │    └─ResBlock: 2-9                                                        --
# │    │    └─ReLU: 3-19                                                      --
# │    │    └─Sequential: 3-20                                                137,952
# │    │    └─Identity: 3-21                                                  --
# │    └─ResBlock: 2-10                                                       --
# │    │    └─ReLU: 3-22                                                      --
# │    │    └─Sequential: 3-23                                                137,952
# │    │    └─Identity: 3-24                                                  --
# │    └─ResBlock: 2-11                                                       --
# │    │    └─ReLU: 3-25                                                      --
# │    │    └─Sequential: 3-26                                                137,952
# │    │    └─Identity: 3-27                                                  --
# │    └─InceptionBlockV3: 2-12                                               --
# │    │    └─ModuleList: 3-28                                                2,902,528
# │    └─ResBlock: 2-13                                                       --
# │    │    └─ReLU: 3-29                                                      --
# │    │    └─Sequential: 3-30                                                1,173,828
# │    │    └─Sequential: 3-31                                                1,331,716
# │    └─ResBlock: 2-14                                                       --
# │    │    └─ReLU: 3-32                                                      --
# │    │    └─Sequential: 3-33                                                1,174,468
# │    │    └─Identity: 3-34                                                  --
# │    └─ResBlock: 2-15                                                       --
# │    │    └─ReLU: 3-35                                                      --
# │    │    └─Sequential: 3-36                                                1,174,468
# │    │    └─Identity: 3-37                                                  --
# │    └─ResBlock: 2-16                                                       --
# │    │    └─ReLU: 3-38                                                      --
# │    │    └─Sequential: 3-39                                                1,174,468
# │    │    └─Identity: 3-40                                                  --
# │    └─ResBlock: 2-17                                                       --
# │    │    └─ReLU: 3-41                                                      --
# │    │    └─Sequential: 3-42                                                1,174,468
# │    │    └─Identity: 3-43                                                  --
# │    └─ResBlock: 2-18                                                       --
# │    │    └─ReLU: 3-44                                                      --
# │    │    └─Sequential: 3-45                                                1,174,468
# │    │    └─Identity: 3-46                                                  --
# │    └─ResBlock: 2-19                                                       --
# │    │    └─ReLU: 3-47                                                      --
# │    │    └─Sequential: 3-48                                                1,174,468
# │    │    └─Identity: 3-49                                                  --
# │    └─ResBlock: 2-20                                                       --
# │    │    └─ReLU: 3-50                                                      --
# │    │    └─Sequential: 3-51                                                1,174,468
# │    │    └─Identity: 3-52                                                  --
# │    └─ResBlock: 2-21                                                       --
# │    │    └─ReLU: 3-53                                                      --
# │    │    └─Sequential: 3-54                                                1,174,468
# │    │    └─Identity: 3-55                                                  --
# │    └─ResBlock: 2-22                                                       --
# │    │    └─ReLU: 3-56                                                      --
# │    │    └─Sequential: 3-57                                                1,174,468
# │    │    └─Identity: 3-58                                                  --
# │    └─InceptionBlockV3: 2-23                                               --
# │    │    └─ModuleList: 3-59                                                3,931,648
# │    └─ResBlock: 2-24                                                       --
# │    │    └─ReLU: 3-60                                                      --
# │    │    └─Sequential: 3-61                                                2,048,448
# │    │    └─Sequential: 3-62                                                4,399,104
# │    └─ResBlock: 2-25                                                       --
# │    │    └─ReLU: 3-63                                                      --
# │    │    └─Sequential: 3-64                                                2,010,816
# │    │    └─Identity: 3-65                                                  --
# │    └─ResBlock: 2-26                                                       --
# │    │    └─ReLU: 3-66                                                      --
# │    │    └─Sequential: 3-67                                                2,010,816
# │    │    └─Identity: 3-68                                                  --
# │    └─ResBlock: 2-27                                                       --
# │    │    └─ReLU: 3-69                                                      --
# │    │    └─Sequential: 3-70                                                2,010,816
# │    │    └─Identity: 3-71                                                  --
# │    └─ResBlock: 2-28                                                       --
# │    │    └─ReLU: 3-72                                                      --
# │    │    └─Sequential: 3-73                                                2,010,816
# │    │    └─Identity: 3-74                                                  --
# ├─Sequential: 1-3                                                           --
# │    └─FlattenFeature: 2-29                                                 --
# │    │    └─Sequential: 3-75                                                --
# │    └─Dropout: 2-30                                                        --
# │    └─Linear: 2-31                                                         88,107
# ====================================================================================================
# Total params: 35,784,343
# Trainable params: 35,784,343
# Non-trainable params: 0
# ====================================================================================================

# %% [markdown]
# # training

# %%
EPOCHS = 10
ACC_ITERS = 1

# %%
trainer = ClassificationTrainer(EPOCHS, DEVICE, ACC_ITERS)
trainer.recorder.increment_data_size(len(train_dataset))

# %%
criterion = trainer.get_criterion(NUM_CLASS)
optim = torch.optim.RMSprop(model.parameters(), lr=1e-3)

# %%
training_loss = trainer.run(train_loader, model, optim, criterion)
# Out:
# Enable AMP: False
# Training...
# 100%|██████████| 832/832 [04:38<00:00,  2.98it/s]
# ------------------------------------
# Epoch 1
# ------------------------------------
# total: 1.6424e-01 (0.00%)
# 100%|██████████| 832/832 [05:30<00:00,  2.51it/s]
# ------------------------------------
# Epoch 2
# ------------------------------------
# total: 8.0836e-02 (-51.00%)
# 100%|██████████| 832/832 [06:23<00:00,  2.17it/s]
# ------------------------------------
# Epoch 3
# ------------------------------------
# total: 3.8480e-02 (-52.00%)
# 100%|██████████| 832/832 [06:42<00:00,  2.07it/s]
# ------------------------------------
# Epoch 4
# ------------------------------------
# total: 1.1786e-02 (-69.00%)
# 100%|██████████| 832/832 [06:08<00:00,  2.25it/s]
# ------------------------------------
# Epoch 5
# ------------------------------------
# total: 5.7343e-03 (-51.00%)
# 100%|██████████| 832/832 [06:14<00:00,  2.22it/s]
# ------------------------------------
# Epoch 6
# ------------------------------------
# total: 4.0041e-03 (-30.00%)
# 100%|██████████| 832/832 [06:31<00:00,  2.13it/s]
# ------------------------------------
# Epoch 7
# ------------------------------------
# total: 2.9131e-03 (-27.00%)
# 100%|██████████| 832/832 [06:28<00:00,  2.14it/s]
# ------------------------------------
# Epoch 8
# ------------------------------------
# total: 2.1371e-03 (-27.00%)
# 100%|██████████| 832/832 [06:15<00:00,  2.21it/s]
# ------------------------------------
# Epoch 9
# ------------------------------------
# total: 1.7739e-03 (-17.00%)
# 100%|██████████| 832/832 [05:43<00:00,  2.42it/s]
# ------------------------------------
# Epoch 10
# ------------------------------------
# total: 1.5530e-03 (-12.00%)

# %%
plt.plot(training_loss)

# %% [markdown]
# # inference

# %%
test_preprocess = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

# %%
test_dataset = GTSRB(
    data_path.as_posix(),
    split="test",
    transform=test_preprocess,
    download=True,
)

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    pin_memory=True,
    num_workers=get_num_workers(),
)

# %%
evaluator = ClassificationEvaluator(NUM_CLASS, DEVICE)

# %%
confusion_matrix = evaluator.run(test_loader, model)
# Out:
# 100%|██████████| 395/395 [01:00<00:00,  6.58it/s]

# %%
per_class_acc = evaluator.get_per_class_accuracy(confusion_matrix)
evaluator.show_per_class_accuracy(range(NUM_CLASS), per_class_acc)
# Out:
# 0         : 0.65
# 1         : 0.9208333333333333
# 2         : 0.7146666666666667
# 3         : 0.9688888888888889
# 4         : 0.8833333333333333
# 5         : 0.9587301587301588
# 6         : 0.66
# 7         : 0.9755555555555555
# 8         : 0.9311111111111111
# 9         : 0.9833333333333333
# 10        : 0.9984848484848485
# 11        : 0.9952380952380953
# 12        : 0.8971014492753623
# 13        : 0.9902777777777778
# 14        : 0.9777777777777777
# 15        : 0.9857142857142858
# 16        : 0.9733333333333334
# 17        : 0.9138888888888889
# 18        : 0.7512820512820513
# 19        : 0.05
# 20        : 0.45555555555555555
# 21        : 0.6444444444444445
# 22        : 0.75
# 23        : 0.9333333333333333
# 24        : 0.6777777777777778
# 25        : 0.7666666666666667
# 26        : 0.6611111111111111
# 27        : 0.5166666666666667
# 28        : 1.0
# 29        : 0.9333333333333333
# 30        : 0.5533333333333333
# 31        : 0.9074074074074074
# 32        : 0.7666666666666667
# 33        : 0.3142857142857143
# 34        : 0.9916666666666667
# 35        : 0.982051282051282
# 36        : 0.925
# 37        : 0.5333333333333333
# 38        : 0.9130434782608695
# 39        : 0.23333333333333334
# 40        : 0.8111111111111111
# 41        : 0.6833333333333333
# 42        : 0.6222222222222222

# %%
per_class_acc.mean()
# Out:
# np.float64(0.7850052944097432)

# %%
evaluator.plot_confusion_matrix(
    confusion_matrix,
    range(NUM_CLASS),
    "Blues",
    annot=False,
    figsize=(8, 6),
)

# %%
model_path = artifact_path / f'inception-resnet-v2.pth'

# %%
torch.save(model.state_dict(), model_path)

# %%
get_file_size(model_path)
# Out:
# '137.14MiB'

# %%
model.load_state_dict(torch.load(model_path.as_posix()))
# Out:
# <All keys matched successfully>
