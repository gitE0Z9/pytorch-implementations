# %%
from pathlib import Path

import matplotlib.pyplot as plt
import torch
import torchinfo
import torchvision
from torch.utils.data import DataLoader
from torchvision import transforms
from tqdm import tqdm

from torchlake.common.controller.recorder import TrainRecorder
from torchlake.common.utils.convert import img_tensor_to_np
from torchlake.common.utils.plot import plot_grids
from torchlake.common.utils.random import generate_normal
from torchlake.image_generation.controllers.trainer_acgan import ACGANTrainer
from torchlake.image_generation.controllers.predictor_cgan import CGANPredictor
from torchlake.image_generation.models.dcgan import DCGANGenerator
from torchlake.image_generation.models.acgan import (
    ACGANDiscriminatorLoss,
    ACGANGeneratorLoss,
    ACGANDiscriminator,
)

# %% [markdown]
# # Setting

# %%
IMAGE_SIZE = 32
BATCH_SIZE = 128

# %%
artifact_path = Path("../../artifacts/acgan")
artifact_path.mkdir(exist_ok=True)

data_path = Path("../../data/fashionMnist")

# %%
# DEVICE = torch.device("cpu")
DEVICE = torch.device("cuda:0")

# %% [markdown]
# # Data

# %%
NUM_CLASS = 10 # len(train_data.classes)

# %%
preprocess = transforms.Compose(
    [
        transforms.Resize(IMAGE_SIZE),
        transforms.ToTensor(),
        lambda x: 2 * x - 1,
    ]
)

# %%
train_data = torchvision.datasets.FashionMNIST(
    root=data_path.as_posix(),
    train=True,
    transform=preprocess,
    download=True,
)

test_data = torchvision.datasets.FashionMNIST(
    root=data_path.as_posix(),
    train=False,
    transform=preprocess,
    download=True,
)

# %%
# 資料集繪圖
plot_grids(
    [*img_tensor_to_np(torch.stack([train_data[i][0] for i in range(9)]))],
    num_row=3,
    num_col=3,
    cmap="gray",
)

# %%
import torch.nn.functional as F

def cond_collate_fn(batch):
    x, y = [], []
    for img, label in batch:
        x.append(img)
        y.append(label)
        
    # B, C, H, W # B*C, H, W
    y = torch.LongTensor(y)
    return torch.stack(x), y, F.one_hot(y, NUM_CLASS).float()

# %%
train_loader = DataLoader(
    train_data,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=True,
    collate_fn=cond_collate_fn,
)

test_loader = DataLoader(
    test_data,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=True,
    collate_fn=cond_collate_fn,
)

# %%
for x, y, c in train_loader:
    print(x.shape, y.shape, c.shape)
    break
# Out:
# torch.Size([128, 1, 32, 32]) torch.Size([128]) torch.Size([128, 10])

# %% [markdown]
# # model

# %%
LATENT_DIM = 128
HIDDEN_DIM = 1024

# %%
generator = DCGANGenerator(
    LATENT_DIM + NUM_CLASS,
    output_size=1,
    hidden_dim=HIDDEN_DIM,
    init_shape=(2, 2),
).to(DEVICE)
discriminator = ACGANDiscriminator(
    1,
    NUM_CLASS,
    hidden_dim=HIDDEN_DIM // 16,
    image_shape=(IMAGE_SIZE, IMAGE_SIZE),
).to(DEVICE)

# %%
torchinfo.summary(generator)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# DCGANGenerator                           --
# ├─Sequential: 1-1                        --
# │    └─Linear: 2-1                       569,344
# │    └─Unflatten: 2-2                    --
# │    └─BatchNorm2d: 2-3                  2,048
# ├─Sequential: 1-2                        --
# │    └─ConvBNReLU: 2-4                   --
# │    │    └─ConvTranspose2d: 3-1         8,388,608
# │    │    └─BatchNorm2d: 3-2             1,024
# │    │    └─ReLU: 3-3                    --
# │    └─ConvBNReLU: 2-5                   --
# │    │    └─ConvTranspose2d: 3-4         2,097,152
# │    │    └─BatchNorm2d: 3-5             512
# │    │    └─ReLU: 3-6                    --
# │    └─ConvBNReLU: 2-6                   --
# │    │    └─ConvTranspose2d: 3-7         524,288
# │    │    └─BatchNorm2d: 3-8             256
# │    │    └─ReLU: 3-9                    --
# │    └─ConvBNReLU: 2-7                   --
# │    │    └─ConvTranspose2d: 3-10        131,072
# │    │    └─BatchNorm2d: 3-11            128
# │    │    └─ReLU: 3-12                   --
# ├─Sequential: 1-3                        --
# │    └─Conv2d: 2-8                       577
# │    └─Tanh: 2-9                         --
# =================================================================
# Total params: 11,715,009
# Trainable params: 11,715,009
# Non-trainable params: 0
# =================================================================

# %%
torchinfo.summary(discriminator)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ACGANDiscriminator                       --
# ├─Sequential: 1-1                        --
# │    └─Conv2dNormActivation: 2-1         --
# │    │    └─Conv2d: 3-1                  640
# │    │    └─LeakyReLU: 3-2               --
# ├─Sequential: 1-2                        --
# │    └─Conv2dNormActivation: 2-2         --
# │    │    └─Conv2d: 3-3                  73,728
# │    │    └─BatchNorm2d: 3-4             256
# │    │    └─LeakyReLU: 3-5               --
# │    └─Conv2dNormActivation: 2-3         --
# │    │    └─Conv2d: 3-6                  294,912
# │    │    └─BatchNorm2d: 3-7             512
# │    │    └─LeakyReLU: 3-8               --
# │    └─Conv2dNormActivation: 2-4         --
# │    │    └─Conv2d: 3-9                  1,179,648
# │    │    └─BatchNorm2d: 3-10            1,024
# │    │    └─LeakyReLU: 3-11              --
# │    └─Conv2dNormActivation: 2-5         --
# │    │    └─Conv2d: 3-12                 4,718,592
# │    │    └─BatchNorm2d: 3-13            2,048
# │    │    └─LeakyReLU: 3-14              --
# ├─Sequential: 1-3                        --
# │    └─FlattenFeature: 2-6               --
# │    │    └─Sequential: 3-15             --
# │    └─Linear: 2-7                       11,275
# =================================================================
# Total params: 6,282,635
# Trainable params: 6,282,635
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# # train

# %%
from typing import Generator

def noise_generator(batch_size: int, device: torch.device) -> Generator[torch.Tensor, None, None]:
    while True:
        yield generate_normal(batch_size, LATENT_DIM).to(device)

# %%
EPOCH = 10

# %%
trainer = ACGANTrainer(EPOCH, DEVICE)

# %%
recorder = TrainRecorder(total_epoch=EPOCH, num_loss=2, loss_names=["discriminator", "generator"])
recorder.increment_data_size(len(train_data))

# %%
LR = 5e-5
BETA = (0.5, 0.999)

# %%
criterion_g = ACGANGeneratorLoss()
criterion_d = ACGANDiscriminatorLoss()
optim_g = torch.optim.Adam(generator.parameters(), lr=LR, betas=BETA)
optim_d = torch.optim.Adam(discriminator.parameters(), lr=LR, betas=BETA)

# %%
training_losses = trainer.run(
    train_loader,
    noise_generator,
    generator,
    discriminator,
    optim_g,
    optim_d,
    criterion_g,
    criterion_d,
    recorder=recorder,
)
# Out:
# Enable AMP: False
# 100%|██████████| 468/468 [00:36<00:00, 12.78it/s]
# ------------------------------------
# Epoch 1
# ------------------------------------
# discriminator: 1.3641e-02 (0.00%)
# generator: 1.1218e-02 (0.00%)
# 100%|██████████| 468/468 [00:34<00:00, 13.72it/s]
# ------------------------------------
# Epoch 2
# ------------------------------------
# discriminator: 7.0995e-03 (-48.00%)
# generator: 1.3859e-02 (24.00%)
# 100%|██████████| 468/468 [00:23<00:00, 19.56it/s]
# ------------------------------------
# Epoch 3
# ------------------------------------
# discriminator: 7.9111e-03 (11.00%)
# generator: 1.3266e-02 (-4.00%)
# 100%|██████████| 468/468 [00:23<00:00, 19.76it/s]
# ------------------------------------
# Epoch 4
# ------------------------------------
# discriminator: 7.9301e-03 (0.00%)
# generator: 1.3251e-02 (0.00%)
# 100%|██████████| 468/468 [00:23<00:00, 19.91it/s]
# ------------------------------------
# Epoch 5
# ------------------------------------
# discriminator: 7.7377e-03 (-2.00%)
# generator: 1.3266e-02 (0.00%)
# 100%|██████████| 468/468 [00:23<00:00, 19.93it/s]
# ------------------------------------
# Epoch 6
# ------------------------------------
# discriminator: 7.3326e-03 (-5.00%)
# generator: 1.3721e-02 (3.00%)
# 100%|██████████| 468/468 [00:23<00:00, 19.85it/s]
# ------------------------------------
# Epoch 7
# ------------------------------------
# discriminator: 6.3928e-03 (-13.00%)
# generator: 1.5421e-02 (12.00%)
# 100%|██████████| 468/468 [00:23<00:00, 20.01it/s]
# ------------------------------------
# Epoch 8
# ------------------------------------
# discriminator: 5.5843e-03 (-13.00%)
# generator: 1.7393e-02 (13.00%)
# 100%|██████████| 468/468 [00:23<00:00, 19.77it/s]
# ------------------------------------
# Epoch 9
# ------------------------------------
# discriminator: 4.7768e-03 (-14.00%)
# generator: 1.9913e-02 (14.00%)
# 100%|██████████| 468/468 [00:23<00:00, 19.78it/s]
# ------------------------------------
# Epoch 10
# ------------------------------------
# discriminator: 4.5630e-03 (-4.00%)
# generator: 2.0705e-02 (4.00%)

# %%
plt.plot(training_losses[0], label="discriminator loss")
plt.plot(training_losses[1], label="generator loss")
plt.legend(bbox_to_anchor=(1, 1))

# %% [markdown]
# # evaluation

# %%
TEST_BATCH_SIZE = 16

# %%
for i, c in enumerate(train_data.classes): print(i, ":", c)
# Out:
# 0 : T-shirt/top
# 1 : Trouser
# 2 : Pullover
# 3 : Dress
# 4 : Coat
# 5 : Sandal
# 6 : Shirt
# 7 : Sneaker
# 8 : Bag
# 9 : Ankle boot

# %%
predictor = CGANPredictor(DEVICE)

noise = noise_generator(TEST_BATCH_SIZE, DEVICE)

# Trouser
gen_img = predictor.run(noise, F.one_hot(torch.full((TEST_BATCH_SIZE,), 1), NUM_CLASS).to(DEVICE), generator)

plot_grids(
    img_tensor_to_np(gen_img),
    num_row=4,
    num_col=4,
    is_gray_scale=True,
    figsize=(4,4),
)

# Dress
gen_img = predictor.run(noise, F.one_hot(torch.full((TEST_BATCH_SIZE,), 3), NUM_CLASS).to(DEVICE), generator)
    
plot_grids(
    img_tensor_to_np(gen_img),
    num_row=4,
    num_col=4,
    is_gray_scale=True,
    figsize=(4,4),
)

# Ankle boot
gen_img = predictor.run(noise, F.one_hot(torch.full((TEST_BATCH_SIZE,), 9), NUM_CLASS).to(DEVICE), generator)

plot_grids(
    img_tensor_to_np(gen_img),
    num_row=4,
    num_col=4,
    is_gray_scale=True,
    figsize=(4,4),
)

# %%
# 區別是否為真實圖片
generator.eval()
discriminator.eval()
with torch.no_grad():
    hits = 0.0
    for img, _, _ in tqdm(test_loader):
        img = img.to(DEVICE)
        hits += discriminator(img)[:, 0].sigmoid().gt(0.5).sum().item()

    print(hits / len(test_data))
# Out:
# 100%|██████████| 78/78 [00:02<00:00, 34.35it/s]
# 0.6099

# %%
# 區別是否為合成圖片
generator.eval()
discriminator.eval()
with torch.no_grad():
    hits = 0.0
    for img, _, c in tqdm(test_loader):
        c = c.to(DEVICE)
        noise = torch.cat((generate_normal(len(img), LATENT_DIM).to(DEVICE), c), 1)
        gen_img = generator(noise)
        
        c = c[:, :, None, None].expand(len(img), NUM_CLASS, IMAGE_SIZE, IMAGE_SIZE)
        hits += discriminator(gen_img)[:, 0].sigmoid().gt(0.5).sum().item()
    print(hits / len(test_data))
# Out:
# 100%|██████████| 78/78 [00:03<00:00, 23.60it/s]
# 0.175

# %%
from torchlake.common.controller.weight_manager import WeightManager

weight_manager = WeightManager(artifact_path.joinpath('acgan.pth').as_posix())

# %%
generator_path = weight_manager.get_filename()
generator_path
# Out:
# WindowsPath('../../artifacts/acgan/acgan.pth')

# %%
weight_manager.save_weight(generator.state_dict(), generator_path)
# Out:
# Save weight to ..\..\artifacts\acgan\acgan.pth, model size is 44.71MiB

# %%
weight_manager.load_weight(generator_path, generator)
